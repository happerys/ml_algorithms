# %% [markdown]
# ## Linear Regression Algorithm
# 基本形式
# ------
# > 给定由$d$个属性描述的示例$x=(x_1;x_2;\dots ;x_d)$，其中$x_i$是$x$的第$i$个属性上的取值，线性模型$(linear\; model)$试图学得一个通过属性的线性组合来进行预测的函数，即
# $$f(x)=\omega_1x_1+\omega_2x_2+\dots+\omega_dx_d+b$$
# > 一般用向量的形式书写
# $$f(\bf x)=\omega^{\bf T} \bf x+b$$
# > 其中，$\omega = (\omega_1;\omega_2;\dots;\omega_d)$
#
# 线性回归
# ------
# > 给定数据集$D=\{(x_1,y_1),(x_2,y_2),\dots,(x_m,y_m)\}$，其中，$x_i=(x_{i1};x_{i2};\dots;x_{id}),y_i\subseteq R$。“线性回归”$（linear\; regression）$试图学得一个线性模型以尽可能地预测实值输出标记。
#
# > 线性回归试图学得$f(x_i)=\omega x_i + b$，使得$f(x_i)\approx y_i$
#
# > **均方误差**是回归任务中最常用的性能度量，因此可以试图让均方误差最小化来求解$\omega$和$b$
# $$\begin{align}
# (\omega^*,b^*) &={arg \; min}_{(\omega,b)}\sum_{i=1}^m{(f(x_i)-y_i)}^2  \\
# &={arg \; min}_{(\omega,b)}\sum_{i=1}^m{(y_i-\omega x_i - b)}^2 \qquad (1)
# \end{align}$$
#
# > 均方误差有非常好的几何意义，它对应了重用的欧几里得距离或简称“欧氏距离”$(Eucliean\;distanc)$. 基于均方误差最小化来进行模型求解的方法称为“最小二乘法”$（least\;square\;method）$. 在线性回归中，最小二乘法就是试图找到一条直线，使所有样本到直线上的欧氏距离之和最小。
#
# > 求解$\omega$和$b$使$E_{(\omega, b)}=\sum_{i=1}^m(y_i-\omega x_i -b)^2$最小化的过程，称为线性回归模型的最小二乘“参数估计”（$parameter\;estimetion$）.我们可以将$E_{(\omega,b)}$分别对$\omega$和$b$求导，得到
# $$\begin{align}
# & \frac{\partial E_{(\omega, b)}}{\partial \omega }=2\bigl(\omega \sum_{i=1}^m x_i^2-\sum_{i=1}^m(y_i-b)x_i\bigr)\qquad (2) \\
# & \frac{\partial E_{(\omega, b)}}{\partial b}=2\bigl(mb-\sum_{i=1}^m(y_i-\omega x_i)\bigr)\qquad (3)
# \end{align}$$
#
# > 然后令(2)、(3)为零可得$\omega$和$b$最优解的闭式（$closed-form$）解
# $$\begin{align}
# & \omega=\frac{\sum_{i=1}^my_i(x_i-\bar{x})}{\sum_{i=1}^mx_i^2-{\frac{1}{m}}{\bigl({\sum_{i=1}^mx_i}\bigr)}^2}\qquad (4) \\
# & b={\frac{1}{m}}\sum_{i=1}^m(y_i-\omega x_i)\qquad(5)
# \end{align}$$
# > 其中$\bar{x}=\frac{1}{m}\sum_{i=1}^mx_i$为$x$的均值.
#
# 多元线性回归$(multivariate\;linear\;regression)$
# ----------------------------------------
# > 对于$\;f(\bf {x_i})={\bf \omega}^T \bf {x_i} + b\;$把$\omega$和$b$吸收入向量形式$\;\hat{\omega}=(\omega;b)\;$，相应的，把数据集$D$表示为一个$m\times (d+1)$大小的矩阵$X$，其中每行对于于一个示例，该行前$d$个属性值，最后一个元素恒置为1，即
# $$X=
#     \begin{pmatrix}
#         x_{11} & x_{12} & \cdots & x_{1d} & 1 \\
#         x_{21} & x_{22} & \cdots & x_{2d} & 1 \\
#         \vdots & \vdots & \vdots & \vdots & \vdots \\
#         x_{m1} & x_{m2} & \cdots & x_{md} & 1 \\
#     \end{pmatrix}
#     =
#     \begin{pmatrix}
#        x_1^T & 1 \\
#        x_2^T & 1 \\
#        \vdots & \vdots \\
#        x_m^T & 1\\
#     \end{pmatrix}
# $$
# > 再把标记也写成向量的形式$y=(y_1;y_2;\cdots;y_m)$，则根据(1)式有
# $$\hat{\omega}^*=arg\;min_{\hat{\omega}}(y-X\hat{\omega})^T(y-X\hat{\omega})$$
# > 令$E_{\hat{\omega}}=\frac{1}{2}(X\hat{\omega}-y)^2$，转换为矩阵运算如下
# $$\begin{align}
# E_{\hat{\omega}} &=\frac{1}{2}(X\hat{\omega}-y)^T(X\hat{\omega}-y) \\
# & =\frac{1}{2}(\hat{\omega}^T X^T-y^T)(X\hat{\omega}-y) \\
# & =\frac{1}{2}(\hat{\omega}^TX^TX\hat{\omega}-\hat{\omega}^TX^Ty-y^TX\hat{\omega}+y^Ty) \\
# & =\frac{1}{2}(\hat{\omega}^TX^TX\hat{\omega}-y^TX\hat{\omega}-y^TX\hat{\omega}+y^Ty) \\
# & =\frac{1}{2}(\hat{\omega}^TX^TX\hat{\omega}-2y^TX\hat{\omega}+y^Ty)\\
# \end{align}$$
#
# > 对$\hat{\omega}$求导得到
# >> 矩阵求导公式：
# $$\begin{align}
# \frac{dAB}{dB}&=A^T \\
# \frac{dA^TB}{dA}&=B \\
# \frac{dX^TAX}{dX}&=2AX \\
# \end{align}$$
#
# >
# $$\begin{align}
# \frac{\partial E_{\hat{\omega}}}{\partial \hat{\omega}} &= \frac{1}{2}(2X^TX\omega-2X^Ty-0)    \\
# &=\frac{1}{2}(2X^TX\omega-2X^Ty)  \\
# &=X^TX\omega-X^Ty  \\
# \end{align}$$
#
# > 当$X^TX$为满秩矩阵（$full-rank \; matrix$）或正定矩阵（$positive\;definite\;matrix$）时，令 $\frac{\partial E_{\hat{\omega}}}{\partial \hat{\omega}}=0$
# $$\begin{align}
# X^TX\hat{\omega}-X^Ty&=0 \\
# X^TX\hat{\omega}&=X^Ty \\
# \hat{\omega}&=(X^TX)^{-1}X^Ty \qquad (6)\\
# \end{align}$$
# > 其中$(X^TX)^{-1}$是矩阵$(X^TX)$的逆矩阵。令$\; \hat{x}_i=(x_i, 1)\;$故，可得多元线性回归模型为
# $$f(\hat{x}_i)={\hat{x}_i}^T(X^TX)^{-1}X^Ty$$
#
# >> **上述内容部分参考周志华老师的《机器学习》**

# %% [markdown]
# 正则化(regularization)
# ------------------
# > 对于(6)式，如果**矩阵$X$有$d>m$，则$X^TX$不是满秩的**，或者**某些特征之间的线性相关性比较大时**，$\hat{\omega}$会有无穷多个解。
# 如果从所有可行解里随机选一个的话，很可能并不是真正好的解，此时模型overfitting了。解决 overfitting 最常用的办法就是 regularization
#
# ### 1、LASSO Regression(least absolute shrinkage and selection operator)
# > LASSO Regression表示如下：
# $$\begin{align}
# E_{\hat{\omega}} &=\frac{1}{2}(X\hat{\omega}-y)^T(X\hat{\omega}-y)+\lambda \begin{Vmatrix} \omega \end{Vmatrix}_1\\
# & =\frac{1}{2}(\hat{\omega}^TX^TX\hat{\omega}-2y^TX\hat{\omega}+y^Ty)+\lambda \begin{Vmatrix} \omega \end{Vmatrix}_1
# \end{align}$$
#
# > **1、gradient存在，此时$\bar{\omega}^j\neq 0$**
# $$\left. \frac{\partial E_{\hat{\omega}}}{\partial \hat{\omega}} \right| _{\; \omega^j}=0$$
#
# > 所以$$(X^TX\omega - X^Ty)_j + \lambda \cdot sgn(\omega^j)=0$$
#
# > 其中，$\lambda \geq 0$，所以$$\omega^j=\omega^{*j}-\lambda \cdot sgn(\omega^j)$$
#
# > 可得，$\omega^j$和$\omega^{*j}$是同号的，$$\omega^j=\omega^{*j}-\lambda \cdot sgn(\omega^j)=sgn(\omega^{*j})(| \omega^{*j} |-\lambda)$$
# $$|\omega_{*j}|-\lambda=|\omega^j|\geq 0$$
#
# > 最终可得$$\omega^j=sgn(\omega^{*j})(|\omega^{*j}|-\lambda)_+$$
#
# > 其中$(X)_+$表示取$X$的正整数部分，$(X)_+=max(x,0)$
#
# > **2、gradient不存在，此时$\bar{\omega}^j = 0$**
#
# > **定理：** *点$x_o$是凸函数$f$的全局最小值，当且仅当$0\in \partial f(x_o)$*
#
# > 如果$\omega^j$ 是最小值，则
# $$0 \in \partial E_{\hat{\omega}}=(X^TX\omega-X^Ty)+\lambda\cdot e = \omega-\omega^*+\lambda\cdot e$$
# > 其中$e$是一个向量，每一个元素$e^j\in [-1, 1]$，使得$0=-\omega^{*j}+\lambda\cdot e^j$成立。因此，$$|\omega^{*j}|=\lambda|e^j|\leq \lambda$$
#
# >> 综上所述，可得LASSO Regression的$\omega$求解公式：$$\omega^j=sgn(\omega^{*j}){(|\omega^{*j}|-\lambda)}_+$$
#
# > LASSO是一个convex optimization问题，它的优良性质是能产生稀疏性，导致$\omega$中许多项变成0。
#
#
# > ### LASSO Regression 另解
#
# > LASSO的cost function的两部分求解:
#
# > 1.RSS部分
# $$RSS(\omega)=\sum^m_{i=1}(y_i-\sum^n_{j=1}x_{ij}\omega_j)^2$$
# > 对$RSS(\omega)$关于$\omega$求导：
# $$\begin{align}
# \frac{\partial {RSS(\omega)}} {\partial{\omega_k}} &=-2{\sum^m_{i=1}}x_{ik}{(y_i-\sum^n_{j=1} x_{ij}\omega_j)} \\
# &=-2\sum^m_{i=1}(x_{ik}y_i-x_{ik}\sum^n_{j=1,j\neq k}x_{ij}\omega_j-x^2_{ik}\omega_k) \\
# &=-2\sum^m_{i=1} x_{ik}(y_i-\sum^n_{j=1,j\neq k}x_{ij}\omega_j)+2\omega_k\sum^m_{i=1}x^2_{ik} \\
# \end{align}$$
#
# > 令$p_k=\sum^m_{i=1} x_{ik}(y_i-\sum^n_{j=1,j\neq k}x_{ij}\omega_j)$，$z_k=\omega_k\sum^m_{i=1}x^2_{ik}$，得到：
# $$\frac{\partial {RSS(\omega)}} {\partial{\omega_k}}=-2p_k+2z_k\omega_k$$
#
# > 2.正则项
#
# >关于惩罚项的求导使用subgradient(次梯度)
#
# $$\lambda\frac{\partial{\sum^n_{i=1}|\omega_j|}}{\partial\omega_k}=
# \left\{
# \begin{array}{ll}
# -\lambda & \omega_k\lt0 \\
# [-\lambda,\lambda] & \omega_k=0 \\
# \lambda & \omega_k \gt 0
# \end{array}
# \right.$$
#
# > 整体偏导数：
# $$\begin{align}
# \frac{\partial {f(\omega)}} {\partial{\omega_k}} & =-2p_k+2z_k\omega_k+
# \left\{
# \begin{array}{ll}
# -\lambda & \omega_k\lt0 \\
# [-\lambda,\lambda] & \omega_k=0 \\
# \lambda & \omega_k \gt 0
# \end{array}
# \right. \\
# &=
# \left\{
# \begin{array}{ll}
# 2z_k\omega_k -2p_k -\lambda & \omega_k\lt0 \\
# [-2p_k-\lambda,-2p_k+\lambda] & \omega_k=0 \\
# 2z_k\omega_k -2p_k + \lambda & \omega_k \gt 0
# \end{array}
# \right.
# \end{align}$$
#
# > 令$\frac{\partial {f(\omega)}} {\partial{\omega_k}}=0$得到
# $$\hat{\omega}=\left\{
# \begin{array}{ll}
# \frac{(p_k+\frac{\lambda}{2})}{z+k} & p_k\lt -\frac{\lambda}{2}\\
# 0\\
# \frac{(p_k-\frac{\lambda}{2})}{z+k} & p_k\gt -\frac{\lambda}{2}
# \end{array}
# \right. $$
#
# > Lasso Regression 的损失函数不是连续可导的，由于L1范数用的是绝对值之和，导致损失函数有不可导的点。也就是说，最小二乘法、梯度下降法、牛顿法与拟牛顿法对它统统失效了。对于Lasso Regression采用坐标轴下降法（coordinate descent）和最小角回归法（Least Angle Regression，LARS）求极值解法。
#
# > #### 坐标轴下降法（coordinate descent）
#
# > 坐标轴下降法是每次选择一个维度的参数进行一维优化，然后不断的迭代对多个维度进行更新直到函数收敛。
#
# > 坐标轴下降法顾名思义，是沿着坐标轴的方向去下降，这和梯度下降不同。梯度下降是沿着梯度的负方向下降。不过梯度下降和坐标轴下降的共性就都是迭代法，通过启发式的方式一步步迭代求解函数的最小值。
#
# > 坐标轴下降法主要依据结论：一个可微的凸函数$J(\theta)$, 其中$\theta$是nx1的向量，即有n个维度。如果在某一点$\bar{\theta}$，使得$J(\theta)$在每一个坐标轴$\bar{\theta}_i$(i = 1,2,...,n)上都是最小值，那么$J(\bar{\theta}_i)$就是一个全局的最小值。
#
# > 于是我们的优化目标就是在$\theta$的n个坐标轴上(或者说向量的方向上)对损失函数做迭代的下降，当所有的坐标轴上的$\theta_i$(i = 1,2,...,n)都达到收敛时，我们的损失函数最小，此时的$\theta$即为我们要求的结果。
#
# > 算法过程：
# >> 1.首先，给$\theta$向量随机取一个初值。记为$\theta^{(0)}$ ，上标括号里面的数字代表迭代的轮数，当前初始轮数为0.
#
# >> 2.对于第k轮的迭代。从$\theta^{(k)}_1$开始，到$\theta^{(k)}_n$为止，依次求$\theta^{(k)}_i$。$\theta^{(k)}_i$的表达式如下：
#
# >> $$\theta^{(k)}_i \in \underbrace{argmin}_{\theta_i} J(\theta^{(k)}_1,\theta^{(k)}_2,\cdots,\theta^{(k)}_{i-1},\theta_i,\theta^{(k-1)}_{i+1},\cdots,\theta^{(k-1)}_n)$$
#
# >> 也就是说$\theta^{(k)}_i$是使$J(\theta^{(k)}_1,\theta^{(k)}_2,\cdots,\theta^{(k)}_{i-1},\theta_i,\theta^{(k-1)}_{i+1},\cdots,\theta^{(k-1)}_n)$最小化时候的$\theta_i$的值。此时$J(\theta)$只有$\theta^{(k)}_i$是变量，其余均为常量，因此最小值容易通过求导求得。
#
# >> 具体一点，在第k轮，$\theta$向量的n个维度的迭代式如下：
# $$\begin{align}
# & \theta^{(k)}_1 \in \underbrace{argmin}_{\theta_1} J(\theta_1,\theta^{(k-1)}_2,\cdots,\theta^{(k-1)}_n) \\
# & \theta^{(k)}_2 \in \underbrace{argmin}_{\theta_2} J(\theta^{(k)}_1,\theta_2,\theta^{(k-1)}_3,\cdots,\theta^{(k-1)}_n) \\
# & \cdots \\
# & \theta^{(k)}_n \in \underbrace{argmin}_{\theta_n} J(\theta^{(k)}_1,\theta^{(k)}_2,\cdots,\theta^{(k)}_{n-1},\theta_n) \\
# \end{align}$$
#
# >>3.检查$\theta^{(k)}$向量和$\theta^{(k-1)}$向量在各个维度上的变化情况，如果在所有维度上变化都足够小，那么$\theta^{(k)}$即为最终结果，否则转入2，继续第k+1轮的迭代。
#
# > 以上就是坐标轴下降法的求极值过程，可以和梯度下降做一个比较：
#
# >> a) 坐标轴下降法在每次迭代中在当前点处沿一个坐标方向进行一维搜索 ，固定其他的坐标方向，找到一个函数的局部极小值。而梯度下降总是沿着梯度的负方向求函数的局部最小值。
#
# >> b) 坐标轴下降优化方法是一种非梯度优化算法。在整个过程中依次循环使用不同的坐标方向进行迭代，一个周期的一维搜索迭代过程相当于一个梯度下降的迭代。
#
# >> c) 梯度下降是利用目标函数的导数来确定搜索方向的，该梯度方向可能不与任何坐标轴平行。而坐标轴下降法法是利用当前坐标方向进行搜索，不需要求目标函数的导数，只按照某一坐标方向进行搜索最小值。
#
# >> d) 两者都是迭代方法，且每一轮迭代，都需要O(mn)的计算量(m为样本数，n为系数向量的维度)

# %% [markdown]
# ### 2、Ridge Regression
# > Ridge Regression表示如下：
# $$$$\begin{align}
# E_{\hat{\omega}} &=\frac{1}{2}(X\hat{\omega}-y)^T(X\hat{\omega}-y)+\frac{\lambda}{2} \begin{Vmatrix} \omega \end{Vmatrix}^2\\
# & =\frac{1}{2}(\hat{\omega}^TX^TX\hat{\omega}-2y^TX\hat{\omega}+y^Ty)+\frac{\lambda}{2} \begin{Vmatrix} \omega \end{Vmatrix}^2
# \end{align}$$$$
#
# > 对损失函数关于$\hat{\omega}$求偏导：
# $$\begin{align}
# \frac{\partial E_{\hat{\omega}}}{\partial \hat{\omega}} &= \frac{1}{2}(2X^TX\omega-2X^Ty-0)+ \lambda \omega  \\
# &=\frac{1}{2}(2X^TX\omega-2X^Ty)+ \lambda \omega  \\
# &=X^TX\omega-X^Ty+ \lambda \omega  \\
# \end{align}$$
#
# > 令$\frac{\partial E_{\hat{\omega}}}{\partial \hat{\omega}}=0$得：
# $$\hat{\omega}=(X^TX+\lambda I)^{-1}\cdot X^Ty$$
#
# > $X^TX$加上一个单位矩阵是的矩阵变成非奇异矩阵并可以进行求逆运算。
#
# > #### 随机梯度下降法(Stochastic Gradient Descent, SGD)
#
# > Ridge Regression损失函数关于$\hat{\omega}$偏导数存在，故使用随机梯度下降法(Stochastic Gradient Descent, SGD)求解$\omega$
#
# > 为了求解$\theta=[\theta_1,\theta_2,...]$的值，可以先对其赋一组初值，然后改变$\theta$的值，使得$J(\theta)$最小。函数$J(\theta)$在其负梯度方向下降最快，所以只要使得每个参数θ按函数负梯度方向改变，则$J(\theta)$能最快找到最小值。即
#
# > **代数描述法**
# $$f(\omega)=\frac{1}{m}\sum^m_{i=1}E_i(\omega)^2+\lambda\sum^n_{j=1}\omega^2_j$$
# $$\frac{\partial f}{\partial \omega_j}(\omega)=(\frac{1}{m}\sum^m_{i=1}2E_i(a)\cdot x^{(i)}_j )+2\lambda\omega_j$$
# $$\omega_j:=\omega_j-\alpha\cdot(2E_i(a)\cdot x^{(i)}_j)+2\lambda\omega_j$$
#
# > **矩阵描述法**
# $$\omega:=\omega-\alpha(X^TX\omega-X^Ty+ \lambda \omega)$$
#
# > 其中$\alpha$ 为学习率，即往每次下降最快的方向走多远，一般通过交叉验证选取较好值。
#
# > 使用随机梯度下降算法前对数据进行中心化和标准化处理：
# >>机器学习算法中通常要对原始数据进行中心化和标准化处理，也就是需要将数据的均值调整到0，标准差调整为1, 计算过程是将所有数据减去平均值后再除以标准差；之所以需要进行中心化其实就是个平移过程，将所有数据的中心平移到原点。而标准化则是使得所有数据的不同特征都有相同的尺度Scale, 这样在使用梯度下降法以及其他方法优化的时候不同特征参数的影响程度就会一致了。
#
# > **Ridge Regression 的性质：**
# >> 1、当岭参数 $\lambda = 0$ 时，得到的解是最小二乘解
#
# >> 2、当岭参数 $\lambda$ 趋向更大时，岭回归系数 $w_i$ 趋向于0，约束项 t 很小
#
# > 批量梯度下降（Batch gradient descent）每次迭代都用所有训练样本。随机梯度下降（Stochastic gradient descent，SGD）每次迭代都用一个训练样本，这个训练样本是随机选择的。当训练样本较多的时候，随机梯度下降法比批量梯度下降法更快找到最优参数。批量梯度下降法一个训练集只能产生一个结果。而SGD每次运行都会产生不同的结果。SGD也可能找不到最小值，因为升级权重的时候只用一个训练样本。它的近似值通常足够接近最小值，尤其是处理残差平方和这类凸函数的时候。

# %% [markdown]
# ### 3、LOSSA & Ridge Regression 的认识
# > Lasso回归和岭回归最重要的区别是，岭回归中随着惩罚项增加时，所有项都会减小，但是仍然保持非0的状态，然而Lasso回归中，随着惩罚项的增加，越来越多的参数会直接变为0，正是这个优势使得Lasso回归容易用作特征的选择（对应参数非0项），因此Lasso回归可以说能很好的保留那些具有重要意义的特征而去掉那些意义不大甚至毫无意义的特征，而岭回归永远不会认为一个特征是毫无意义的。
#
# > 模型选择的典型方法是正则化。正则化是结构风险最小化策略的实现，是在经验风险上加一个正则化项(regularizer)或罚项(penalty term)。正则化项一般是模型复杂度的单调递增函数，模型越复杂，正则化值就越大。比如，正则化项可以是模型参数向量的范数。
#
# > 正则化符合奥卡姆剃刀(Occam's razor)原理。奥卡姆剃刀原理应用于模型选择时变为以下想法：在所有可能选择的模型中，能够很好地解释已知数据并且十分简单才是最好的模型，也就是应该选择的模型。从贝叶斯估计的角度来看，正则化项对应于模型的先验概率。可以假设复杂的模型有较大的先验概率，简单的模型有较小的先验概率。
#
# > 概括而言就是一句话总结：1范数和0范数可以实现稀疏，L1因具有比L0更好的优化求解特性而被广泛应用。然后L2范数是指向量各元素的平方和然后求平方根。我们让L2范数的正则项||W||2最小，可以使得W的每个元素都很小，都接近于0，但与L1范数不同，它不会让它等于0，而是接近于0。
#
# > 从贝叶斯角度而言，不同的regularization代表了对权重使用不同的先验分布
#
# > Lasso是一阶正则化，岭回归是二阶正则化。Lasso的出发点是减少overfit，而岭回归一般认为是处理多重共线性的一种做法，当然它也有降低overfit的作用。lasso实际上是挑选自变量的一种做法，岭回归是压缩某些系数。二者都会在训练集上放大误差，但是均能在测试集上减小估计误差（理论上）。
#
# > 总结：
# >> 1.默认情况下选用L2正则。
#
# >> 2.如若认为少数特征有用，可以用L1正则。
#
# >> 3.如若认为少数特征有用，但特征数大于样本数，则选择ElasticNet函数。
#
# > 如果发生过拟合， 参数$\omega$一般是比较大的值，加入惩罚项后，只要控制λ的大小，当λ很大时，θ1到θn就会很小，即达到了约束数量庞大的特征的目的。
#
# > 从贝叶斯的角度来分析， 正则化是为模型参数估计增加一个先验知识，先验知识会引导损失函数最小值过程朝着约束方向迭代。 L1正则是Laplace先验，L2是高斯先验。整个最优化问题可以看做是一个最大后验估计，其中正则化项对应后验估计中的先验信息，损失函数对应后验估计中的似然函数，两者的乘积即对应贝叶斯最大后验估计。
#
# >  直接使用最小二乘法可能会遇到的问题：
# >>（1）只有当矩阵X是满秩的时候，才可以用最小二乘法。也就是多个因变量必须是相互独立的，如果相互之间关联较强，或者样本点比较少的时候，很可能造成X就不是满秩的，因为$X^{-1}$是不可逆的。
#
# >>（2）计算大型逆矩阵复杂度高，在处理大规模数据的时候，耗时长。

# %% [markdown]
# # Python实现
# ### 1、最小二乘

# %%
import numpy as np 

# 没有正则化的最小二乘，该方法返回对应的系数向量
def matrix_lstsqr(x, y):
    # 构造特征矩阵
    X = np.vstack([x, np.ones(len(x))]).T
    # 返回系数矩阵
    return (np.linalg.inv(X.T.dot(X)).dot(X.T)).dot(y)

# %%
import matplotlib.pyplot as plt
import random

# 生成 x
x = np.arange(-5, 5, 0.1)
# y = 8*x+90
y = [(8*a + 90) for a in x]

# 生成拟合图像
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, color='g', linestyle='-', marker='')

x_a = [b1*(random.randint(90,120))/100 for b1 in x]
y_a = [b2*(random.randint(90,120))/100 for b2 in y]
ax.plot(x_a, y_a, color='r', linestyle='', marker='.')
plt.show()

# 通过最小二乘法求解 y = 8x+90 的系数
matrix_lstsqr(x, y)
# Out:
# array([  8.,  90.])

# %% [markdown]
# ### 2、LASSO Regression实现

# %%
def load_data(filename):
    ''' 
        加载数据
    '''
    X, Y = [], []
    with open(filename, 'r') as f:
        for line in f:
            splited_line = [float(i) for i in line.split()]
            x, y = splited_line[: -1], splited_line[-1]
            X.append(x)
            Y.append(y)
    X, Y = np.matrix(X), np.matrix(Y).T
    return X, Y

def standarize(X):
    ''' 
        中心化 & 标准化数据 (零均值, 单位标准差)
    '''
    std_deviation = np.std(X, 0)
    mean = np.mean(X, 0)
    return (X - mean) / std_deviation

def std_linreg(X, Y):
    xTx = X.T*X
    if np.linalg.det(xTx) == 0:
        print('xTx is a singular matrix')
        return
    return xTx.I*X.T*Y

def get_corrcoef(X, Y):
    # X Y 的协方差
    cov = np.mean(X*Y) - np.mean(X)*np.mean(Y)
    return cov/(np.var(X)*np.var(Y))**0.5

# %%
import itertools
from math import exp
import numpy as np
import matplotlib.pyplot as plt

def lasso_regression(X, y, lambd=0.2, threshold=0.1):
    ''' 
        通过坐标下降(coordinate descent)法获取LASSO回归系数
    '''
    # 计算残差平方和
    rss = lambda X, y, w: (y - X*w).T*(y - X*w)
    # 初始化回归系数w.
    m, n = X.shape
    w = np.matrix(np.zeros((n, 1)))
    r = rss(X, y, w)
    # 使用坐标下降法优化回归系数w
    niter = itertools.count(1)
    for it in niter:
        for k in range(n):
            # 计算常量值z_k和p_k
            z_k = (X[:, k].T*X[:, k])[0, 0]
            p_k = 0
            for i in range(m):
                p_k += X[i, k]*(y[i, 0] - sum([X[i, j]*w[j, 0] for j in range(n) if j != k]))
            
            # 分情况计算w_k
            if p_k < -lambd/2:
                w_k = (p_k + lambd/2)/z_k
            elif p_k > lambd/2:
                w_k = (p_k - lambd/2)/z_k
            else:
                w_k = 0
            w[k, 0] = w_k
        r_prime = rss(X, y, w)
        delta = abs(r_prime - r)[0, 0]
        r = r_prime
        # print('Iteration: {}, delta = {}'.format(it, delta))
        if delta < threshold:
            break
    return w

# %%
# 验证LASSO的坐标下降算法
X, y = load_data('abalone.txt')
X, y = standarize(X), standarize(y)
w = lasso_regression(X, y, lambd=10)
y_prime = X*w
print("系数矩阵", w)

# 计算相关系数
corrcoef = get_corrcoef(np.array(y.reshape(1, -1)), np.array(y_prime.reshape(1, -1)))
print('Correlation coefficient: {}'.format(corrcoef))
# Out:
# 系数矩阵 [[ 0.01491625]
#  [ 0.        ]
#  [ 0.36007948]
#  [ 0.15395325]
#  [ 1.00970149]
#  [-1.23437005]
#  [-0.22746198]
#  [ 0.50638396]]
# Correlation coefficient: 0.7255254877587117

# %%
def lasso_traj(X, y, ntest=30):
    ''' 
        获取回归系数轨迹矩阵
    '''
    _, n = X.shape
    ws = np.zeros((ntest, n))
    for i in range(ntest):
        w = lasso_regression(X, y, lambd=exp(i-10))
        ws[i, :] = w.T
        # print('lambda = e^({}), w = {}'.format(i-10, w.T[0, :]))
    return ws

ntest=30
# 绘制轨迹
ws = lasso_traj(X, y, ntest= 30)
fig = plt.figure()
ax = fig.add_subplot(111)

lambdas = [i-10 for i in range(ntest)]
ax.plot(lambdas, ws)

plt.show()

# %% [markdown]
# > 通过与岭轨迹图进行对比发现，随着$\lambda$的增大，系数逐渐趋近于0，但是岭回归没有系数真正为0，而lasso中不断有系数变为0.

# %% [markdown]
# ### 3、Ridge Regression
# #### 矩阵计算

# %%
def ridge_regression(X, y, lambd=0.2):
    ''' 
        获取岭回归系数
    '''
    XTX = X.T*X
    m, _ = XTX.shape
    I = np.matrix(np.eye(m))
    w = (XTX + lambd*I).I*X.T*y
    return w

# %%
def ridge_traj(X, y, ntest=30):
    ''' 获取岭轨迹矩阵
    '''
    _, n = X.shape
    ws = np.zeros((ntest, n))
    for i in range(ntest):
        w = ridge_regression(X, y, lambd=exp(i-10))
        ws[i, :] = w.T
    return ws

ntest = 30
# 加载数据
X, y = load_data('abalone.txt')

# 中心化 & 标准化
X, y = standarize(X), standarize(y)

# 测试数据和训练数据
w_test, errors = [], []
for i in range(ntest):
    lambd = exp(i - 10)
    # 训练数据
    X_train, y_train = X[: 180, :], y[: 180, :]
    # 测试数据
    X_test, y_test = X[180: -1, :], y[180: -1, :]

    # 岭回归系数
    w = ridge_regression(X_train, y_train, lambd)
    error = np.std(X_test*w - y_test)
    w_test.append(w)
    errors.append(error)

# 选择误差最小的回归系数
w_best, e_best = min(zip(w_test, errors), key=lambda x: x[1])
print('Best w: {}, best error: {}'.format(w_best, e_best))

y_prime = X*w_best
# 计算相关系数
corrcoef = get_corrcoef(np.array(y.reshape(1, -1)),
                        np.array(y_prime.reshape(1, -1)))
print('Correlation coefficient: {}'.format(corrcoef))

# 绘制岭轨迹
ws = ridge_traj(X, y, ntest)
fig = plt.figure()
ax = fig.add_subplot(111)

lambdas = [i-10 for i in range(ntest)]
ax.plot(lambdas, ws)

plt.show()
# Out:
# Best w: [[ 0.01013554]
#  [-0.01118452]
#  [ 0.68269791]
#  [-0.18625909]
#  [ 0.56556456]
#  [-0.76039839]
#  [-0.0587618 ]
#  [ 0.40240551]], best error: 0.742140703149925
# Correlation coefficient: 0.6748460114148542

# %% [markdown]
# > 可以知道求得的岭系数 $w_i$ 是岭参数 $\lambda$ 的函数，不同的 $\lambda$ 得到不同的岭参数 $w_i$ , 因此我们可以增大 $\lambda$ 的值来得到岭回归系数的变化，以及岭参数的变化轨迹图(岭迹图), 不存在奇异性时，岭迹图应稳定的逐渐趋向于0。
#
# > 通过岭迹图我们可以:
#
# >>观察较佳的 $\lambda$ 取值;
#
# >>观察变量是否有多重共线性.
#
# > 图绘制了回归系数 $w_i$ 与 $log(\lambda)$ 的关系，在最左边 $\lambda$ 系数最小时，可以得到所有系数的原始值(与标准线性回归相同); 而在右边，系数全部缩减为0, 从不稳定趋于稳定；为了定量的找到最佳参数值，还需要进行交叉验证。要判断哪些变量对结果的预测最具影响力，可以观察他们的系数大小即可。

# %% [markdown]
# #### 随机梯度下降算法计算

# %%
import numpy as np

def RidgeGradientDescent(x, y, alpha, iters, L):
    x=np.matrix(x)
    y=np.matrix(y).transpose()
    m, n = np.shape(x)
    beta = np.matrix(np.ones(n)).transpose()
    XT = x.transpose()
    for i in range(0, iters):
        y_hat = np.dot(x, beta)
        residuals = y_hat - y
        MSE = (residuals.transpose()*residuals)/len(x)
        print("iteration:", i, "MSE:", MSE)
        ols_gradient = np.dot(XT, residuals) / m
        beta = beta - alpha * (ols_gradient + (L/m)*beta)
    return beta

# %%
from sklearn import datasets
diabetes = datasets.load_diabetes()

X = diabetes.data
y = diabetes.target
intercept = np.ones(len(X))
X = np.append(intercept, X)
X = np.reshape(X,(442,11))

from scipy import stats
Z = stats.zscore(X, axis=0)
Y = stats.zscore(y)

Mybetas = RidgeGradientDescent(Z,Y,.1,5000,.1)
print(Mybetas)
# Out:
# iteration: 0 MSE: [[ 119.51143329]]
# iteration: 1 MSE: [[ 1.65192878]]
# iteration: 2 MSE: [[ 1.00329653]]
# iteration: 3 MSE: [[ 0.99968294]]
# iteration: 4 MSE: [[ 0.99961919]]
# iteration: 5 MSE: [[ 0.99957517]]
# iteration: 6 MSE: [[ 0.99953146]]
# iteration: 7 MSE: [[ 0.99948795]]
# iteration: 8 MSE: [[ 0.99944464]]
# iteration: 9 MSE: [[ 0.99940153]]
# iteration: 10 MSE: [[ 0.99935861]]
# iteration: 11 MSE: [[ 0.99931589]]
# iteration: 12 MSE: [[ 0.99927336]]
# iteration: 13 MSE: [[ 0.99923103]]
# iteration: 14 MSE: [[ 0.99918889]]
# iteration: 15 MSE: [[ 0.99914694]]
# iteration: 16 MSE: [[ 0.99910517]]
# iteration: 17 MSE: [[ 0.9990636]]
# iteration: 18 MSE: [[ 0.99902222]]
# iteration: 19 MSE: [[ 0.99898102]]
# iteration: 20 MSE: [[ 0.99894002]]
# iteration: 21 MSE: [[ 0.99889919]]
# iteration: 22 MSE: [[ 0.99885855]]
# iteration: 23 MSE: [[ 0.99881809]]
# iteration: 24 MSE: [[ 0.99877782]]
# iteration: 25 MSE: [[ 0.99873773]]
# iteration: 26 MSE: [[ 0.99869781]]
# iteration: 27 MSE: [[ 0.99865808]]
# iteration: 28 MSE: [[ 0.99861852]]
# iteration: 29 MSE: [[ 0.99857915]]
# iteration: 30 MSE: [[ 0.99853995]]
# iteration: 31 MSE: [[ 0.99850092]]
# iteration: 32 MSE: [[ 0.99846207]]
# iteration: 33 MSE: [[ 0.99842339]]
# iteration: 34 MSE: [[ 0.99838489]]
# iteration: 35 MSE: [[ 0.99834656]]
# iteration: 36 MSE: [[ 0.9983084]]
# iteration: 37 MSE: [[ 0.99827041]]
# iteration: 38 MSE: [[ 0.99823259]]
# iteration: 39 MSE: [[ 0.99819493]]
# iteration: 40 MSE: [[ 0.99815745]]
# iteration: 41 MSE: [[ 0.99812013]]
# iteration: 42 MSE: [[ 0.99808298]]
# iteration: 43 MSE: [[ 0.99804599]]
# iteration: 44 MSE: [[ 0.99800917]]
# iteration: 45 MSE: [[ 0.99797251]]
# iteration: 46 MSE: [[ 0.99793601]]
# iteration: 47 MSE: [[ 0.99789967]]
# iteration: 48 MSE: [[ 0.9978635]]
# iteration: 49 MSE: [[ 0.99782748]]
# iteration: 50 MSE: [[ 0.99779163]]
# iteration: 51 MSE: [[ 0.99775593]]
# iteration: 52 MSE: [[ 0.99772039]]
# iteration: 53 MSE: [[ 0.99768501]]
# iteration: 54 MSE: [[ 0.99764978]]
# iteration: 55 MSE: [[ 0.99761471]]
# iteration: 56 MSE: [[ 0.99757979]]
# iteration: 57 MSE: [[ 0.99754503]]
# iteration: 58 MSE: [[ 0.99751042]]
# iteration: 59 MSE: [[ 0.99747596]]
# iteration: 60 MSE: [[ 0.99744165]]
# iteration: 61 MSE: [[ 0.9974075]]
# iteration: 62 MSE: [[ 0.99737349]]
# iteration: 63 MSE: [[ 0.99733963]]
# iteration: 64 MSE: [[ 0.99730592]]
# iteration: 65 MSE: [[ 0.99727236]]
# iteration: 66 MSE: [[ 0.99723895]]
# iteration: 67 MSE: [[ 0.99720568]]
# iteration: 68 MSE: [[ 0.99717255]]
# iteration: 69 MSE: [[ 0.99713957]]
# iteration: 70 MSE: [[ 0.99710674]]
# iteration: 71 MSE: [[ 0.99707405]]
# iteration: 72 MSE: [[ 0.9970415]]
# iteration: 73 MSE: [[ 0.99700909]]
# iteration: 74 MSE: [[ 0.99697682]]
# iteration: 75 MSE: [[ 0.9969447]]
# iteration: 76 MSE: [[ 0.99691271]]
# iteration: 77 MSE: [[ 0.99688086]]
# iteration: 78 MSE: [[ 0.99684915]]
# iteration: 79 MSE: [[ 0.99681758]]
# iteration: 80 MSE: [[ 0.99678615]]
# iteration: 81 MSE: [[ 0.99675485]]
# iteration: 82 MSE: [[ 0.99672369]]
# iteration: 83 MSE: [[ 0.99669266]]
# iteration: 84 MSE: [[ 0.99666176]]
# iteration: 85 MSE: [[ 0.996631]]
# iteration: 86 MSE: [[ 0.99660038]]
# iteration: 87 MSE: [[ 0.99656988]]
# iteration: 88 MSE: [[ 0.99653952]]
# iteration: 89 MSE: [[ 0.99650929]]
# iteration: 90 MSE: [[ 0.99647919]]
# iteration: 91 MSE: [[ 0.99644922]]
# iteration: 92 MSE: [[ 0.99641937]]
# iteration: 93 MSE: [[ 0.99638966]]
# iteration: 94 MSE: [[ 0.99636007]]
# iteration: 95 MSE: [[ 0.99633061]]
# iteration: 96 MSE: [[ 0.99630128]]
# iteration: 97 MSE: [[ 0.99627208]]
# iteration: 98 MSE: [[ 0.996243]]
# iteration: 99 MSE: [[ 0.99621404]]
# iteration: 100 MSE: [[ 0.99618521]]
# iteration: 101 MSE: [[ 0.9961565]]
# iteration: 102 MSE: [[ 0.99612792]]
# iteration: 103 MSE: [[ 0.99609945]]
# iteration: 104 MSE: [[ 0.99607111]]
# iteration: 105 MSE: [[ 0.99604289]]
# iteration: 106 MSE: [[ 0.9960148]]
# iteration: 107 MSE: [[ 0.99598682]]
# iteration: 108 MSE: [[ 0.99595896]]
# iteration: 109 MSE: [[ 0.99593122]]
# iteration: 110 MSE: [[ 0.9959036]]
# iteration: 111 MSE: [[ 0.99587609]]
# iteration: 112 MSE: [[ 0.99584871]]
# iteration: 113 MSE: [[ 0.99582144]]
# iteration: 114 MSE: [[ 0.99579428]]
# iteration: 115 MSE: [[ 0.99576725]]
# iteration: 116 MSE: [[ 0.99574032]]
# iteration: 117 MSE: [[ 0.99571352]]
# iteration: 118 MSE: [[ 0.99568682]]
# iteration: 119 MSE: [[ 0.99566024]]
# iteration: 120 MSE: [[ 0.99563377]]
# iteration: 121 MSE: [[ 0.99560742]]
# iteration: 122 MSE: [[ 0.99558118]]
# iteration: 123 MSE: [[ 0.99555504]]
# iteration: 124 MSE: [[ 0.99552902]]
# iteration: 125 MSE: [[ 0.99550311]]
# iteration: 126 MSE: [[ 0.99547731]]
# iteration: 127 MSE: [[ 0.99545162]]
# iteration: 128 MSE: [[ 0.99542603]]
# iteration: 129 MSE: [[ 0.99540056]]
# iteration: 130 MSE: [[ 0.99537519]]
# iteration: 131 MSE: [[ 0.99534993]]
# iteration: 132 MSE: [[ 0.99532478]]
# iteration: 133 MSE: [[ 0.99529973]]
# iteration: 134 MSE: [[ 0.99527479]]
# iteration: 135 MSE: [[ 0.99524995]]
# iteration: 136 MSE: [[ 0.99522522]]
# iteration: 137 MSE: [[ 0.9952006]]
# iteration: 138 MSE: [[ 0.99517607]]
# iteration: 139 MSE: [[ 0.99515165]]
# iteration: 140 MSE: [[ 0.99512733]]
# iteration: 141 MSE: [[ 0.99510312]]
# iteration: 142 MSE: [[ 0.99507901]]
# iteration: 143 MSE: [[ 0.99505499]]
# iteration: 144 MSE: [[ 0.99503108]]
# iteration: 145 MSE: [[ 0.99500727]]
# iteration: 146 MSE: [[ 0.99498356]]
# iteration: 147 MSE: [[ 0.99495995]]
# iteration: 148 MSE: [[ 0.99493644]]
# iteration: 149 MSE: [[ 0.99491303]]
# iteration: 150 MSE: [[ 0.99488971]]
# iteration: 151 MSE: [[ 0.99486649]]
# iteration: 152 MSE: [[ 0.99484337]]
# iteration: 153 MSE: [[ 0.99482035]]
# iteration: 154 MSE: [[ 0.99479742]]
# iteration: 155 MSE: [[ 0.99477459]]
# iteration: 156 MSE: [[ 0.99475186]]
# iteration: 157 MSE: [[ 0.99472922]]
# iteration: 158 MSE: [[ 0.99470667]]
# iteration: 159 MSE: [[ 0.99468422]]
# iteration: 160 MSE: [[ 0.99466186]]
# iteration: 161 MSE: [[ 0.9946396]]
# iteration: 162 MSE: [[ 0.99461743]]
# iteration: 163 MSE: [[ 0.99459535]]
# iteration: 164 MSE: [[ 0.99457336]]
# iteration: 165 MSE: [[ 0.99455146]]
# iteration: 166 MSE: [[ 0.99452966]]
# iteration: 167 MSE: [[ 0.99450794]]
# iteration: 168 MSE: [[ 0.99448632]]
# iteration: 169 MSE: [[ 0.99446479]]
# iteration: 170 MSE: [[ 0.99444334]]
# iteration: 171 MSE: [[ 0.99442199]]
# iteration: 172 MSE: [[ 0.99440072]]
# iteration: 173 MSE: [[ 0.99437955]]
# iteration: 174 MSE: [[ 0.99435846]]
# iteration: 175 MSE: [[ 0.99433745]]
# iteration: 176 MSE: [[ 0.99431654]]
# iteration: 177 MSE: [[ 0.99429571]]
# iteration: 178 MSE: [[ 0.99427497]]
# iteration: 179 MSE: [[ 0.99425431]]
# iteration: 180 MSE: [[ 0.99423374]]
# iteration: 181 MSE: [[ 0.99421326]]
# iteration: 182 MSE: [[ 0.99419286]]
# iteration: 183 MSE: [[ 0.99417254]]
# iteration: 184 MSE: [[ 0.99415231]]
# iteration: 185 MSE: [[ 0.99413216]]
# iteration: 186 MSE: [[ 0.9941121]]
# iteration: 187 MSE: [[ 0.99409212]]
# iteration: 188 MSE: [[ 0.99407222]]
# iteration: 189 MSE: [[ 0.9940524]]
# iteration: 190 MSE: [[ 0.99403266]]
# iteration: 191 MSE: [[ 0.99401301]]
# iteration: 192 MSE: [[ 0.99399344]]
# iteration: 193 MSE: [[ 0.99397394]]
# iteration: 194 MSE: [[ 0.99395453]]
# iteration: 195 MSE: [[ 0.9939352]]
# iteration: 196 MSE: [[ 0.99391595]]
# iteration: 197 MSE: [[ 0.99389678]]
# iteration: 198 MSE: [[ 0.99387768]]
# iteration: 199 MSE: [[ 0.99385867]]
# iteration: 200 MSE: [[ 0.99383973]]
# iteration: 201 MSE: [[ 0.99382087]]
# iteration: 202 MSE: [[ 0.99380209]]
# iteration: 203 MSE: [[ 0.99378338]]
# iteration: 204 MSE: [[ 0.99376476]]
# iteration: 205 MSE: [[ 0.99374621]]
# iteration: 206 MSE: [[ 0.99372773]]
# iteration: 207 MSE: [[ 0.99370933]]
# iteration: 208 MSE: [[ 0.99369101]]
# iteration: 209 MSE: [[ 0.99367276]]
# iteration: 210 MSE: [[ 0.99365458]]
# iteration: 211 MSE: [[ 0.99363649]]
# iteration: 212 MSE: [[ 0.99361846]]
# iteration: 213 MSE: [[ 0.99360051]]
# iteration: 214 MSE: [[ 0.99358263]]
# iteration: 215 MSE: [[ 0.99356483]]
# iteration: 216 MSE: [[ 0.9935471]]
# iteration: 217 MSE: [[ 0.99352944]]
# iteration: 218 MSE: [[ 0.99351185]]
# iteration: 219 MSE: [[ 0.99349433]]
# iteration: 220 MSE: [[ 0.99347689]]
# iteration: 221 MSE: [[ 0.99345952]]
# iteration: 222 MSE: [[ 0.99344222]]
# iteration: 223 MSE: [[ 0.99342499]]
# iteration: 224 MSE: [[ 0.99340783]]
# iteration: 225 MSE: [[ 0.99339074]]
# iteration: 226 MSE: [[ 0.99337371]]
# iteration: 227 MSE: [[ 0.99335676]]
# iteration: 228 MSE: [[ 0.99333988]]
# iteration: 229 MSE: [[ 0.99332307]]
# iteration: 230 MSE: [[ 0.99330632]]
# iteration: 231 MSE: [[ 0.99328965]]
# iteration: 232 MSE: [[ 0.99327304]]
# iteration: 233 MSE: [[ 0.9932565]]
# iteration: 234 MSE: [[ 0.99324002]]
# iteration: 235 MSE: [[ 0.99322362]]
# iteration: 236 MSE: [[ 0.99320728]]
# iteration: 237 MSE: [[ 0.993191]]
# iteration: 238 MSE: [[ 0.99317479]]
# iteration: 239 MSE: [[ 0.99315865]]
# iteration: 240 MSE: [[ 0.99314258]]
# iteration: 241 MSE: [[ 0.99312656]]
# iteration: 242 MSE: [[ 0.99311062]]
# iteration: 243 MSE: [[ 0.99309474]]
# iteration: 244 MSE: [[ 0.99307892]]
# iteration: 245 MSE: [[ 0.99306317]]
# iteration: 246 MSE: [[ 0.99304748]]
# iteration: 247 MSE: [[ 0.99303185]]
# iteration: 248 MSE: [[ 0.99301629]]
# iteration: 249 MSE: [[ 0.99300079]]
# iteration: 250 MSE: [[ 0.99298536]]
# iteration: 251 MSE: [[ 0.99296998]]
# iteration: 252 MSE: [[ 0.99295467]]
# iteration: 253 MSE: [[ 0.99293942]]
# iteration: 254 MSE: [[ 0.99292423]]
# iteration: 255 MSE: [[ 0.99290911]]
# iteration: 256 MSE: [[ 0.99289404]]
# iteration: 257 MSE: [[ 0.99287904]]
# iteration: 258 MSE: [[ 0.99286409]]
# iteration: 259 MSE: [[ 0.99284921]]
# iteration: 260 MSE: [[ 0.99283438]]
# iteration: 261 MSE: [[ 0.99281962]]
# iteration: 262 MSE: [[ 0.99280492]]
# iteration: 263 MSE: [[ 0.99279027]]
# iteration: 264 MSE: [[ 0.99277569]]
# iteration: 265 MSE: [[ 0.99276116]]
# iteration: 266 MSE: [[ 0.99274669]]
# iteration: 267 MSE: [[ 0.99273228]]
# iteration: 268 MSE: [[ 0.99271793]]
# iteration: 269 MSE: [[ 0.99270363]]
# iteration: 270 MSE: [[ 0.9926894]]
# iteration: 271 MSE: [[ 0.99267522]]
# iteration: 272 MSE: [[ 0.9926611]]
# iteration: 273 MSE: [[ 0.99264703]]
# iteration: 274 MSE: [[ 0.99263302]]
# iteration: 275 MSE: [[ 0.99261907]]
# iteration: 276 MSE: [[ 0.99260517]]
# iteration: 277 MSE: [[ 0.99259133]]
# iteration: 278 MSE: [[ 0.99257754]]
# iteration: 279 MSE: [[ 0.99256381]]
# iteration: 280 MSE: [[ 0.99255014]]
# iteration: 281 MSE: [[ 0.99253652]]
# iteration: 282 MSE: [[ 0.99252295]]
# iteration: 283 MSE: [[ 0.99250944]]
# iteration: 284 MSE: [[ 0.99249599]]
# iteration: 285 MSE: [[ 0.99248258]]
# iteration: 286 MSE: [[ 0.99246923]]
# iteration: 287 MSE: [[ 0.99245594]]
# iteration: 288 MSE: [[ 0.9924427]]
# iteration: 289 MSE: [[ 0.99242951]]
# iteration: 290 MSE: [[ 0.99241637]]
# iteration: 291 MSE: [[ 0.99240329]]
# iteration: 292 MSE: [[ 0.99239026]]
# iteration: 293 MSE: [[ 0.99237728]]
# iteration: 294 MSE: [[ 0.99236435]]
# iteration: 295 MSE: [[ 0.99235147]]
# iteration: 296 MSE: [[ 0.99233865]]
# iteration: 297 MSE: [[ 0.99232587]]
# iteration: 298 MSE: [[ 0.99231315]]
# iteration: 299 MSE: [[ 0.99230048]]
# iteration: 300 MSE: [[ 0.99228786]]
# iteration: 301 MSE: [[ 0.99227529]]
# iteration: 302 MSE: [[ 0.99226277]]
# iteration: 303 MSE: [[ 0.9922503]]
# iteration: 304 MSE: [[ 0.99223788]]
# iteration: 305 MSE: [[ 0.99222551]]
# iteration: 306 MSE: [[ 0.99221319]]
# iteration: 307 MSE: [[ 0.99220091]]
# iteration: 308 MSE: [[ 0.99218869]]
# iteration: 309 MSE: [[ 0.99217651]]
# iteration: 310 MSE: [[ 0.99216439]]
# iteration: 311 MSE: [[ 0.99215231]]
# iteration: 312 MSE: [[ 0.99214028]]
# iteration: 313 MSE: [[ 0.9921283]]
# iteration: 314 MSE: [[ 0.99211636]]
# iteration: 315 MSE: [[ 0.99210447]]
# iteration: 316 MSE: [[ 0.99209263]]
# iteration: 317 MSE: [[ 0.99208084]]
# iteration: 318 MSE: [[ 0.99206909]]
# iteration: 319 MSE: [[ 0.9920574]]
# iteration: 320 MSE: [[ 0.99204574]]
# iteration: 321 MSE: [[ 0.99203414]]
# iteration: 322 MSE: [[ 0.99202257]]
# iteration: 323 MSE: [[ 0.99201106]]
# iteration: 324 MSE: [[ 0.99199959]]
# iteration: 325 MSE: [[ 0.99198817]]
# iteration: 326 MSE: [[ 0.99197679]]
# iteration: 327 MSE: [[ 0.99196546]]
# iteration: 328 MSE: [[ 0.99195417]]
# iteration: 329 MSE: [[ 0.99194292]]
# iteration: 330 MSE: [[ 0.99193173]]
# iteration: 331 MSE: [[ 0.99192057]]
# iteration: 332 MSE: [[ 0.99190946]]
# iteration: 333 MSE: [[ 0.99189839]]
# iteration: 334 MSE: [[ 0.99188737]]
# iteration: 335 MSE: [[ 0.99187639]]
# iteration: 336 MSE: [[ 0.99186546]]
# iteration: 337 MSE: [[ 0.99185456]]
# iteration: 338 MSE: [[ 0.99184371]]
# iteration: 339 MSE: [[ 0.99183291]]
# iteration: 340 MSE: [[ 0.99182214]]
# iteration: 341 MSE: [[ 0.99181142]]
# iteration: 342 MSE: [[ 0.99180074]]
# iteration: 343 MSE: [[ 0.99179011]]
# iteration: 344 MSE: [[ 0.99177951]]
# iteration: 345 MSE: [[ 0.99176896]]
# iteration: 346 MSE: [[ 0.99175845]]
# iteration: 347 MSE: [[ 0.99174798]]
# iteration: 348 MSE: [[ 0.99173755]]
# iteration: 349 MSE: [[ 0.99172716]]
# iteration: 350 MSE: [[ 0.99171682]]
# iteration: 351 MSE: [[ 0.99170651]]
# iteration: 352 MSE: [[ 0.99169624]]
# iteration: 353 MSE: [[ 0.99168602]]
# iteration: 354 MSE: [[ 0.99167584]]
# iteration: 355 MSE: [[ 0.99166569]]
# iteration: 356 MSE: [[ 0.99165559]]
# iteration: 357 MSE: [[ 0.99164552]]
# iteration: 358 MSE: [[ 0.9916355]]
# iteration: 359 MSE: [[ 0.99162551]]
# iteration: 360 MSE: [[ 0.99161556]]
# iteration: 361 MSE: [[ 0.99160566]]
# iteration: 362 MSE: [[ 0.99159579]]
# iteration: 363 MSE: [[ 0.99158596]]
# iteration: 364 MSE: [[ 0.99157617]]
# iteration: 365 MSE: [[ 0.99156642]]
# iteration: 366 MSE: [[ 0.9915567]]
# iteration: 367 MSE: [[ 0.99154703]]
# iteration: 368 MSE: [[ 0.99153739]]
# iteration: 369 MSE: [[ 0.99152779]]
# iteration: 370 MSE: [[ 0.99151823]]
# iteration: 371 MSE: [[ 0.9915087]]
# iteration: 372 MSE: [[ 0.99149921]]
# iteration: 373 MSE: [[ 0.99148976]]
# iteration: 374 MSE: [[ 0.99148035]]
# iteration: 375 MSE: [[ 0.99147097]]
# iteration: 376 MSE: [[ 0.99146163]]
# iteration: 377 MSE: [[ 0.99145233]]
# iteration: 378 MSE: [[ 0.99144306]]
# iteration: 379 MSE: [[ 0.99143383]]
# iteration: 380 MSE: [[ 0.99142464]]
# iteration: 381 MSE: [[ 0.99141548]]
# iteration: 382 MSE: [[ 0.99140636]]
# iteration: 383 MSE: [[ 0.99139727]]
# iteration: 384 MSE: [[ 0.99138822]]
# iteration: 385 MSE: [[ 0.9913792]]
# iteration: 386 MSE: [[ 0.99137022]]
# iteration: 387 MSE: [[ 0.99136127]]
# iteration: 388 MSE: [[ 0.99135236]]
# iteration: 389 MSE: [[ 0.99134349]]
# iteration: 390 MSE: [[ 0.99133465]]
# iteration: 391 MSE: [[ 0.99132584]]
# iteration: 392 MSE: [[ 0.99131707]]
# iteration: 393 MSE: [[ 0.99130833]]
# iteration: 394 MSE: [[ 0.99129962]]
# iteration: 395 MSE: [[ 0.99129095]]
# iteration: 396 MSE: [[ 0.99128232]]
# iteration: 397 MSE: [[ 0.99127371]]
# iteration: 398 MSE: [[ 0.99126514]]
# iteration: 399 MSE: [[ 0.99125661]]
# iteration: 400 MSE: [[ 0.99124811]]
# iteration: 401 MSE: [[ 0.99123964]]
# iteration: 402 MSE: [[ 0.9912312]]
# iteration: 403 MSE: [[ 0.9912228]]
# iteration: 404 MSE: [[ 0.99121443]]
# iteration: 405 MSE: [[ 0.99120609]]
# iteration: 406 MSE: [[ 0.99119778]]
# iteration: 407 MSE: [[ 0.99118951]]
# iteration: 408 MSE: [[ 0.99118127]]
# iteration: 409 MSE: [[ 0.99117306]]
# iteration: 410 MSE: [[ 0.99116488]]
# iteration: 411 MSE: [[ 0.99115673]]
# iteration: 412 MSE: [[ 0.99114862]]
# iteration: 413 MSE: [[ 0.99114054]]
# iteration: 414 MSE: [[ 0.99113248]]
# iteration: 415 MSE: [[ 0.99112446]]
# iteration: 416 MSE: [[ 0.99111648]]
# iteration: 417 MSE: [[ 0.99110852]]
# iteration: 418 MSE: [[ 0.99110059]]
# iteration: 419 MSE: [[ 0.99109269]]
# iteration: 420 MSE: [[ 0.99108483]]
# iteration: 421 MSE: [[ 0.99107699]]
# iteration: 422 MSE: [[ 0.99106919]]
# iteration: 423 MSE: [[ 0.99106141]]
# iteration: 424 MSE: [[ 0.99105367]]
# iteration: 425 MSE: [[ 0.99104596]]
# iteration: 426 MSE: [[ 0.99103827]]
# iteration: 427 MSE: [[ 0.99103062]]
# iteration: 428 MSE: [[ 0.99102299]]
# iteration: 429 MSE: [[ 0.9910154]]
# iteration: 430 MSE: [[ 0.99100783]]
# iteration: 431 MSE: [[ 0.99100029]]
# iteration: 432 MSE: [[ 0.99099278]]
# iteration: 433 MSE: [[ 0.99098531]]
# iteration: 434 MSE: [[ 0.99097786]]
# iteration: 435 MSE: [[ 0.99097043]]
# iteration: 436 MSE: [[ 0.99096304]]
# iteration: 437 MSE: [[ 0.99095568]]
# iteration: 438 MSE: [[ 0.99094834]]
# iteration: 439 MSE: [[ 0.99094104]]
# iteration: 440 MSE: [[ 0.99093376]]
# iteration: 441 MSE: [[ 0.99092651]]
# iteration: 442 MSE: [[ 0.99091928]]
# iteration: 443 MSE: [[ 0.99091209]]
# iteration: 444 MSE: [[ 0.99090492]]
# iteration: 445 MSE: [[ 0.99089778]]
# iteration: 446 MSE: [[ 0.99089067]]
# iteration: 447 MSE: [[ 0.99088358]]
# iteration: 448 MSE: [[ 0.99087653]]
# iteration: 449 MSE: [[ 0.9908695]]
# iteration: 450 MSE: [[ 0.99086249]]
# iteration: 451 MSE: [[ 0.99085552]]
# iteration: 452 MSE: [[ 0.99084857]]
# iteration: 453 MSE: [[ 0.99084165]]
# iteration: 454 MSE: [[ 0.99083475]]
# iteration: 455 MSE: [[ 0.99082788]]
# iteration: 456 MSE: [[ 0.99082104]]
# iteration: 457 MSE: [[ 0.99081422]]
# iteration: 458 MSE: [[ 0.99080743]]
# iteration: 459 MSE: [[ 0.99080067]]
# iteration: 460 MSE: [[ 0.99079393]]
# iteration: 461 MSE: [[ 0.99078722]]
# iteration: 462 MSE: [[ 0.99078053]]
# iteration: 463 MSE: [[ 0.99077387]]
# iteration: 464 MSE: [[ 0.99076723]]
# iteration: 465 MSE: [[ 0.99076062]]
# iteration: 466 MSE: [[ 0.99075404]]
# iteration: 467 MSE: [[ 0.99074748]]
# iteration: 468 MSE: [[ 0.99074095]]
# iteration: 469 MSE: [[ 0.99073444]]
# iteration: 470 MSE: [[ 0.99072795]]
# iteration: 471 MSE: [[ 0.99072149]]
# iteration: 472 MSE: [[ 0.99071506]]
# iteration: 473 MSE: [[ 0.99070865]]
# iteration: 474 MSE: [[ 0.99070226]]
# iteration: 475 MSE: [[ 0.9906959]]
# iteration: 476 MSE: [[ 0.99068957]]
# iteration: 477 MSE: [[ 0.99068326]]
# iteration: 478 MSE: [[ 0.99067697]]
# iteration: 479 MSE: [[ 0.9906707]]
# iteration: 480 MSE: [[ 0.99066446]]
# iteration: 481 MSE: [[ 0.99065825]]
# iteration: 482 MSE: [[ 0.99065206]]
# iteration: 483 MSE: [[ 0.99064589]]
# iteration: 484 MSE: [[ 0.99063974]]
# iteration: 485 MSE: [[ 0.99063362]]
# iteration: 486 MSE: [[ 0.99062752]]
# iteration: 487 MSE: [[ 0.99062145]]
# iteration: 488 MSE: [[ 0.9906154]]
# iteration: 489 MSE: [[ 0.99060937]]
# iteration: 490 MSE: [[ 0.99060336]]
# iteration: 491 MSE: [[ 0.99059738]]
# iteration: 492 MSE: [[ 0.99059142]]
# iteration: 493 MSE: [[ 0.99058548]]
# iteration: 494 MSE: [[ 0.99057957]]
# iteration: 495 MSE: [[ 0.99057368]]
# iteration: 496 MSE: [[ 0.99056781]]
# iteration: 497 MSE: [[ 0.99056196]]
# iteration: 498 MSE: [[ 0.99055614]]
# iteration: 499 MSE: [[ 0.99055034]]
# iteration: 500 MSE: [[ 0.99054456]]
# iteration: 501 MSE: [[ 0.9905388]]
# iteration: 502 MSE: [[ 0.99053306]]
# iteration: 503 MSE: [[ 0.99052735]]
# iteration: 504 MSE: [[ 0.99052165]]
# iteration: 505 MSE: [[ 0.99051598]]
# iteration: 506 MSE: [[ 0.99051033]]
# iteration: 507 MSE: [[ 0.99050471]]
# iteration: 508 MSE: [[ 0.9904991]]
# iteration: 509 MSE: [[ 0.99049351]]
# iteration: 510 MSE: [[ 0.99048795]]
# iteration: 511 MSE: [[ 0.99048241]]
# iteration: 512 MSE: [[ 0.99047689]]
# iteration: 513 MSE: [[ 0.99047138]]
# iteration: 514 MSE: [[ 0.9904659]]
# iteration: 515 MSE: [[ 0.99046045]]
# iteration: 516 MSE: [[ 0.99045501]]
# iteration: 517 MSE: [[ 0.99044959]]
# iteration: 518 MSE: [[ 0.99044419]]
# iteration: 519 MSE: [[ 0.99043882]]
# iteration: 520 MSE: [[ 0.99043346]]
# iteration: 521 MSE: [[ 0.99042812]]
# iteration: 522 MSE: [[ 0.99042281]]
# iteration: 523 MSE: [[ 0.99041751]]
# iteration: 524 MSE: [[ 0.99041224]]
# iteration: 525 MSE: [[ 0.99040698]]
# iteration: 526 MSE: [[ 0.99040175]]
# iteration: 527 MSE: [[ 0.99039653]]
# iteration: 528 MSE: [[ 0.99039134]]
# iteration: 529 MSE: [[ 0.99038616]]
# iteration: 530 MSE: [[ 0.990381]]
# iteration: 531 MSE: [[ 0.99037587]]
# iteration: 532 MSE: [[ 0.99037075]]
# iteration: 533 MSE: [[ 0.99036565]]
# iteration: 534 MSE: [[ 0.99036057]]
# iteration: 535 MSE: [[ 0.99035551]]
# iteration: 536 MSE: [[ 0.99035047]]
# iteration: 537 MSE: [[ 0.99034545]]
# iteration: 538 MSE: [[ 0.99034045]]
# iteration: 539 MSE: [[ 0.99033546]]
# iteration: 540 MSE: [[ 0.9903305]]
# iteration: 541 MSE: [[ 0.99032555]]
# iteration: 542 MSE: [[ 0.99032063]]
# iteration: 543 MSE: [[ 0.99031572]]
# iteration: 544 MSE: [[ 0.99031083]]
# iteration: 545 MSE: [[ 0.99030596]]
# iteration: 546 MSE: [[ 0.9903011]]
# iteration: 547 MSE: [[ 0.99029627]]
# iteration: 548 MSE: [[ 0.99029145]]
# iteration: 549 MSE: [[ 0.99028665]]
# iteration: 550 MSE: [[ 0.99028187]]
# iteration: 551 MSE: [[ 0.99027711]]
# iteration: 552 MSE: [[ 0.99027236]]
# iteration: 553 MSE: [[ 0.99026764]]
# iteration: 554 MSE: [[ 0.99026293]]
# iteration: 555 MSE: [[ 0.99025824]]
# iteration: 556 MSE: [[ 0.99025356]]
# iteration: 557 MSE: [[ 0.99024891]]
# iteration: 558 MSE: [[ 0.99024427]]
# iteration: 559 MSE: [[ 0.99023965]]
# iteration: 560 MSE: [[ 0.99023505]]
# iteration: 561 MSE: [[ 0.99023046]]
# iteration: 562 MSE: [[ 0.99022589]]
# iteration: 563 MSE: [[ 0.99022134]]
# iteration: 564 MSE: [[ 0.9902168]]
# iteration: 565 MSE: [[ 0.99021229]]
# iteration: 566 MSE: [[ 0.99020779]]
# iteration: 567 MSE: [[ 0.9902033]]
# iteration: 568 MSE: [[ 0.99019884]]
# iteration: 569 MSE: [[ 0.99019439]]
# iteration: 570 MSE: [[ 0.99018995]]
# iteration: 571 MSE: [[ 0.99018554]]
# iteration: 572 MSE: [[ 0.99018114]]
# iteration: 573 MSE: [[ 0.99017675]]
# iteration: 574 MSE: [[ 0.99017239]]
# iteration: 575 MSE: [[ 0.99016804]]
# iteration: 576 MSE: [[ 0.9901637]]
# iteration: 577 MSE: [[ 0.99015938]]
# iteration: 578 MSE: [[ 0.99015508]]
# iteration: 579 MSE: [[ 0.9901508]]
# iteration: 580 MSE: [[ 0.99014653]]
# iteration: 581 MSE: [[ 0.99014227]]
# iteration: 582 MSE: [[ 0.99013804]]
# iteration: 583 MSE: [[ 0.99013381]]
# iteration: 584 MSE: [[ 0.99012961]]
# iteration: 585 MSE: [[ 0.99012542]]
# iteration: 586 MSE: [[ 0.99012124]]
# iteration: 587 MSE: [[ 0.99011708]]
# iteration: 588 MSE: [[ 0.99011294]]
# iteration: 589 MSE: [[ 0.99010881]]
# iteration: 590 MSE: [[ 0.9901047]]
# iteration: 591 MSE: [[ 0.9901006]]
# iteration: 592 MSE: [[ 0.99009652]]
# iteration: 593 MSE: [[ 0.99009245]]
# iteration: 594 MSE: [[ 0.9900884]]
# iteration: 595 MSE: [[ 0.99008437]]
# iteration: 596 MSE: [[ 0.99008035]]
# iteration: 597 MSE: [[ 0.99007634]]
# iteration: 598 MSE: [[ 0.99007235]]
# iteration: 599 MSE: [[ 0.99006837]]
# iteration: 600 MSE: [[ 0.99006441]]
# iteration: 601 MSE: [[ 0.99006047]]
# iteration: 602 MSE: [[ 0.99005653]]
# iteration: 603 MSE: [[ 0.99005262]]
# iteration: 604 MSE: [[ 0.99004871]]
# iteration: 605 MSE: [[ 0.99004483]]
# iteration: 606 MSE: [[ 0.99004095]]
# iteration: 607 MSE: [[ 0.99003709]]
# iteration: 608 MSE: [[ 0.99003325]]
# iteration: 609 MSE: [[ 0.99002942]]
# iteration: 610 MSE: [[ 0.9900256]]
# iteration: 611 MSE: [[ 0.9900218]]
# iteration: 612 MSE: [[ 0.99001801]]
# iteration: 613 MSE: [[ 0.99001424]]
# iteration: 614 MSE: [[ 0.99001048]]
# iteration: 615 MSE: [[ 0.99000674]]
# iteration: 616 MSE: [[ 0.990003]]
# iteration: 617 MSE: [[ 0.98999929]]
# iteration: 618 MSE: [[ 0.98999558]]
# iteration: 619 MSE: [[ 0.98999189]]
# iteration: 620 MSE: [[ 0.98998822]]
# iteration: 621 MSE: [[ 0.98998455]]
# iteration: 622 MSE: [[ 0.98998091]]
# iteration: 623 MSE: [[ 0.98997727]]
# iteration: 624 MSE: [[ 0.98997365]]
# iteration: 625 MSE: [[ 0.98997004]]
# iteration: 626 MSE: [[ 0.98996644]]
# iteration: 627 MSE: [[ 0.98996286]]
# iteration: 628 MSE: [[ 0.98995929]]
# iteration: 629 MSE: [[ 0.98995574]]
# iteration: 630 MSE: [[ 0.9899522]]
# iteration: 631 MSE: [[ 0.98994867]]
# iteration: 632 MSE: [[ 0.98994515]]
# iteration: 633 MSE: [[ 0.98994165]]
# iteration: 634 MSE: [[ 0.98993816]]
# iteration: 635 MSE: [[ 0.98993468]]
# iteration: 636 MSE: [[ 0.98993122]]
# iteration: 637 MSE: [[ 0.98992777]]
# iteration: 638 MSE: [[ 0.98992433]]
# iteration: 639 MSE: [[ 0.98992091]]
# iteration: 640 MSE: [[ 0.98991749]]
# iteration: 641 MSE: [[ 0.98991409]]
# iteration: 642 MSE: [[ 0.98991071]]
# iteration: 643 MSE: [[ 0.98990733]]
# iteration: 644 MSE: [[ 0.98990397]]
# iteration: 645 MSE: [[ 0.98990062]]
# iteration: 646 MSE: [[ 0.98989728]]
# iteration: 647 MSE: [[ 0.98989395]]
# iteration: 648 MSE: [[ 0.98989064]]
# iteration: 649 MSE: [[ 0.98988734]]
# iteration: 650 MSE: [[ 0.98988405]]
# iteration: 651 MSE: [[ 0.98988078]]
# iteration: 652 MSE: [[ 0.98987751]]
# iteration: 653 MSE: [[ 0.98987426]]
# iteration: 654 MSE: [[ 0.98987102]]
# iteration: 655 MSE: [[ 0.98986779]]
# iteration: 656 MSE: [[ 0.98986458]]
# iteration: 657 MSE: [[ 0.98986137]]
# iteration: 658 MSE: [[ 0.98985818]]
# iteration: 659 MSE: [[ 0.989855]]
# iteration: 660 MSE: [[ 0.98985183]]
# iteration: 661 MSE: [[ 0.98984867]]
# iteration: 662 MSE: [[ 0.98984553]]
# iteration: 663 MSE: [[ 0.98984239]]
# iteration: 664 MSE: [[ 0.98983927]]
# iteration: 665 MSE: [[ 0.98983616]]
# iteration: 666 MSE: [[ 0.98983306]]
# iteration: 667 MSE: [[ 0.98982997]]
# iteration: 668 MSE: [[ 0.98982689]]
# iteration: 669 MSE: [[ 0.98982383]]
# iteration: 670 MSE: [[ 0.98982077]]
# iteration: 671 MSE: [[ 0.98981773]]
# iteration: 672 MSE: [[ 0.9898147]]
# iteration: 673 MSE: [[ 0.98981168]]
# iteration: 674 MSE: [[ 0.98980867]]
# iteration: 675 MSE: [[ 0.98980567]]
# iteration: 676 MSE: [[ 0.98980268]]
# iteration: 677 MSE: [[ 0.98979971]]
# iteration: 678 MSE: [[ 0.98979674]]
# iteration: 679 MSE: [[ 0.98979379]]
# iteration: 680 MSE: [[ 0.98979084]]
# iteration: 681 MSE: [[ 0.98978791]]
# iteration: 682 MSE: [[ 0.98978499]]
# iteration: 683 MSE: [[ 0.98978208]]
# iteration: 684 MSE: [[ 0.98977918]]
# iteration: 685 MSE: [[ 0.98977629]]
# iteration: 686 MSE: [[ 0.98977341]]
# iteration: 687 MSE: [[ 0.98977054]]
# iteration: 688 MSE: [[ 0.98976768]]
# iteration: 689 MSE: [[ 0.98976483]]
# iteration: 690 MSE: [[ 0.989762]]
# iteration: 691 MSE: [[ 0.98975917]]
# iteration: 692 MSE: [[ 0.98975635]]
# iteration: 693 MSE: [[ 0.98975355]]
# iteration: 694 MSE: [[ 0.98975075]]
# iteration: 695 MSE: [[ 0.98974797]]
# iteration: 696 MSE: [[ 0.98974519]]
# iteration: 697 MSE: [[ 0.98974243]]
# iteration: 698 MSE: [[ 0.98973967]]
# iteration: 699 MSE: [[ 0.98973693]]
# iteration: 700 MSE: [[ 0.98973419]]
# iteration: 701 MSE: [[ 0.98973147]]
# iteration: 702 MSE: [[ 0.98972875]]
# iteration: 703 MSE: [[ 0.98972605]]
# iteration: 704 MSE: [[ 0.98972335]]
# iteration: 705 MSE: [[ 0.98972067]]
# iteration: 706 MSE: [[ 0.98971799]]
# iteration: 707 MSE: [[ 0.98971533]]
# iteration: 708 MSE: [[ 0.98971267]]
# iteration: 709 MSE: [[ 0.98971002]]
# iteration: 710 MSE: [[ 0.98970739]]
# iteration: 711 MSE: [[ 0.98970476]]
# iteration: 712 MSE: [[ 0.98970214]]
# iteration: 713 MSE: [[ 0.98969954]]
# iteration: 714 MSE: [[ 0.98969694]]
# iteration: 715 MSE: [[ 0.98969435]]
# iteration: 716 MSE: [[ 0.98969177]]
# iteration: 717 MSE: [[ 0.9896892]]
# iteration: 718 MSE: [[ 0.98968664]]
# iteration: 719 MSE: [[ 0.98968409]]
# iteration: 720 MSE: [[ 0.98968155]]
# iteration: 721 MSE: [[ 0.98967902]]
# iteration: 722 MSE: [[ 0.98967649]]
# iteration: 723 MSE: [[ 0.98967398]]
# iteration: 724 MSE: [[ 0.98967147]]
# iteration: 725 MSE: [[ 0.98966898]]
# iteration: 726 MSE: [[ 0.98966649]]
# iteration: 727 MSE: [[ 0.98966401]]
# iteration: 728 MSE: [[ 0.98966155]]
# iteration: 729 MSE: [[ 0.98965909]]
# iteration: 730 MSE: [[ 0.98965664]]
# iteration: 731 MSE: [[ 0.98965419]]
# iteration: 732 MSE: [[ 0.98965176]]
# iteration: 733 MSE: [[ 0.98964934]]
# iteration: 734 MSE: [[ 0.98964692]]
# iteration: 735 MSE: [[ 0.98964452]]
# iteration: 736 MSE: [[ 0.98964212]]
# iteration: 737 MSE: [[ 0.98963973]]
# iteration: 738 MSE: [[ 0.98963735]]
# iteration: 739 MSE: [[ 0.98963498]]
# iteration: 740 MSE: [[ 0.98963262]]
# iteration: 741 MSE: [[ 0.98963026]]
# iteration: 742 MSE: [[ 0.98962792]]
# iteration: 743 MSE: [[ 0.98962558]]
# iteration: 744 MSE: [[ 0.98962325]]
# iteration: 745 MSE: [[ 0.98962093]]
# iteration: 746 MSE: [[ 0.98961862]]
# iteration: 747 MSE: [[ 0.98961631]]
# iteration: 748 MSE: [[ 0.98961402]]
# iteration: 749 MSE: [[ 0.98961173]]
# iteration: 750 MSE: [[ 0.98960945]]
# iteration: 751 MSE: [[ 0.98960718]]
# iteration: 752 MSE: [[ 0.98960492]]
# iteration: 753 MSE: [[ 0.98960267]]
# iteration: 754 MSE: [[ 0.98960042]]
# iteration: 755 MSE: [[ 0.98959819]]
# iteration: 756 MSE: [[ 0.98959596]]
# iteration: 757 MSE: [[ 0.98959374]]
# iteration: 758 MSE: [[ 0.98959152]]
# iteration: 759 MSE: [[ 0.98958932]]
# iteration: 760 MSE: [[ 0.98958712]]
# iteration: 761 MSE: [[ 0.98958493]]
# iteration: 762 MSE: [[ 0.98958275]]
# iteration: 763 MSE: [[ 0.98958058]]
# iteration: 764 MSE: [[ 0.98957841]]
# iteration: 765 MSE: [[ 0.98957625]]
# iteration: 766 MSE: [[ 0.9895741]]
# iteration: 767 MSE: [[ 0.98957196]]
# iteration: 768 MSE: [[ 0.98956983]]
# iteration: 769 MSE: [[ 0.9895677]]
# iteration: 770 MSE: [[ 0.98956558]]
# iteration: 771 MSE: [[ 0.98956347]]
# iteration: 772 MSE: [[ 0.98956137]]
# iteration: 773 MSE: [[ 0.98955927]]
# iteration: 774 MSE: [[ 0.98955718]]
# iteration: 775 MSE: [[ 0.9895551]]
# iteration: 776 MSE: [[ 0.98955303]]
# iteration: 777 MSE: [[ 0.98955096]]
# iteration: 778 MSE: [[ 0.98954891]]
# iteration: 779 MSE: [[ 0.98954685]]
# iteration: 780 MSE: [[ 0.98954481]]
# iteration: 781 MSE: [[ 0.98954277]]
# iteration: 782 MSE: [[ 0.98954075]]
# iteration: 783 MSE: [[ 0.98953872]]
# iteration: 784 MSE: [[ 0.98953671]]
# iteration: 785 MSE: [[ 0.9895347]]
# iteration: 786 MSE: [[ 0.9895327]]
# iteration: 787 MSE: [[ 0.98953071]]
# iteration: 788 MSE: [[ 0.98952873]]
# iteration: 789 MSE: [[ 0.98952675]]
# iteration: 790 MSE: [[ 0.98952478]]
# iteration: 791 MSE: [[ 0.98952281]]
# iteration: 792 MSE: [[ 0.98952086]]
# iteration: 793 MSE: [[ 0.98951891]]
# iteration: 794 MSE: [[ 0.98951696]]
# iteration: 795 MSE: [[ 0.98951503]]
# iteration: 796 MSE: [[ 0.9895131]]
# iteration: 797 MSE: [[ 0.98951118]]
# iteration: 798 MSE: [[ 0.98950926]]
# iteration: 799 MSE: [[ 0.98950735]]
# iteration: 800 MSE: [[ 0.98950545]]
# iteration: 801 MSE: [[ 0.98950356]]
# iteration: 802 MSE: [[ 0.98950167]]
# iteration: 803 MSE: [[ 0.98949979]]
# iteration: 804 MSE: [[ 0.98949792]]
# iteration: 805 MSE: [[ 0.98949605]]
# iteration: 806 MSE: [[ 0.98949419]]
# iteration: 807 MSE: [[ 0.98949233]]
# iteration: 808 MSE: [[ 0.98949049]]
# iteration: 809 MSE: [[ 0.98948865]]
# iteration: 810 MSE: [[ 0.98948681]]
# iteration: 811 MSE: [[ 0.98948498]]
# iteration: 812 MSE: [[ 0.98948316]]
# iteration: 813 MSE: [[ 0.98948135]]
# iteration: 814 MSE: [[ 0.98947954]]
# iteration: 815 MSE: [[ 0.98947774]]
# iteration: 816 MSE: [[ 0.98947595]]
# iteration: 817 MSE: [[ 0.98947416]]
# iteration: 818 MSE: [[ 0.98947238]]
# iteration: 819 MSE: [[ 0.9894706]]
# iteration: 820 MSE: [[ 0.98946883]]
# iteration: 821 MSE: [[ 0.98946707]]
# iteration: 822 MSE: [[ 0.98946531]]
# iteration: 823 MSE: [[ 0.98946356]]
# iteration: 824 MSE: [[ 0.98946182]]
# iteration: 825 MSE: [[ 0.98946008]]
# iteration: 826 MSE: [[ 0.98945835]]
# iteration: 827 MSE: [[ 0.98945662]]
# iteration: 828 MSE: [[ 0.9894549]]
# iteration: 829 MSE: [[ 0.98945319]]
# iteration: 830 MSE: [[ 0.98945148]]
# iteration: 831 MSE: [[ 0.98944978]]
# iteration: 832 MSE: [[ 0.98944809]]
# iteration: 833 MSE: [[ 0.9894464]]
# iteration: 834 MSE: [[ 0.98944472]]
# iteration: 835 MSE: [[ 0.98944304]]
# iteration: 836 MSE: [[ 0.98944137]]
# iteration: 837 MSE: [[ 0.9894397]]
# iteration: 838 MSE: [[ 0.98943805]]
# iteration: 839 MSE: [[ 0.98943639]]
# iteration: 840 MSE: [[ 0.98943475]]
# iteration: 841 MSE: [[ 0.9894331]]
# iteration: 842 MSE: [[ 0.98943147]]
# iteration: 843 MSE: [[ 0.98942984]]
# iteration: 844 MSE: [[ 0.98942822]]
# iteration: 845 MSE: [[ 0.9894266]]
# iteration: 846 MSE: [[ 0.98942499]]
# iteration: 847 MSE: [[ 0.98942338]]
# iteration: 848 MSE: [[ 0.98942178]]
# iteration: 849 MSE: [[ 0.98942019]]
# iteration: 850 MSE: [[ 0.9894186]]
# iteration: 851 MSE: [[ 0.98941701]]
# iteration: 852 MSE: [[ 0.98941544]]
# iteration: 853 MSE: [[ 0.98941386]]
# iteration: 854 MSE: [[ 0.9894123]]
# iteration: 855 MSE: [[ 0.98941074]]
# iteration: 856 MSE: [[ 0.98940918]]
# iteration: 857 MSE: [[ 0.98940763]]
# iteration: 858 MSE: [[ 0.98940609]]
# iteration: 859 MSE: [[ 0.98940455]]
# iteration: 860 MSE: [[ 0.98940301]]
# iteration: 861 MSE: [[ 0.98940149]]
# iteration: 862 MSE: [[ 0.98939996]]
# iteration: 863 MSE: [[ 0.98939845]]
# iteration: 864 MSE: [[ 0.98939694]]
# iteration: 865 MSE: [[ 0.98939543]]
# iteration: 866 MSE: [[ 0.98939393]]
# iteration: 867 MSE: [[ 0.98939243]]
# iteration: 868 MSE: [[ 0.98939094]]
# iteration: 869 MSE: [[ 0.98938946]]
# iteration: 870 MSE: [[ 0.98938798]]
# iteration: 871 MSE: [[ 0.9893865]]
# iteration: 872 MSE: [[ 0.98938503]]
# iteration: 873 MSE: [[ 0.98938357]]
# iteration: 874 MSE: [[ 0.98938211]]
# iteration: 875 MSE: [[ 0.98938066]]
# iteration: 876 MSE: [[ 0.98937921]]
# iteration: 877 MSE: [[ 0.98937777]]
# iteration: 878 MSE: [[ 0.98937633]]
# iteration: 879 MSE: [[ 0.98937489]]
# iteration: 880 MSE: [[ 0.98937347]]
# iteration: 881 MSE: [[ 0.98937204]]
# iteration: 882 MSE: [[ 0.98937063]]
# iteration: 883 MSE: [[ 0.98936921]]
# iteration: 884 MSE: [[ 0.9893678]]
# iteration: 885 MSE: [[ 0.9893664]]
# iteration: 886 MSE: [[ 0.989365]]
# iteration: 887 MSE: [[ 0.98936361]]
# iteration: 888 MSE: [[ 0.98936222]]
# iteration: 889 MSE: [[ 0.98936084]]
# iteration: 890 MSE: [[ 0.98935946]]
# iteration: 891 MSE: [[ 0.98935809]]
# iteration: 892 MSE: [[ 0.98935672]]
# iteration: 893 MSE: [[ 0.98935536]]
# iteration: 894 MSE: [[ 0.989354]]
# iteration: 895 MSE: [[ 0.98935264]]
# iteration: 896 MSE: [[ 0.98935129]]
# iteration: 897 MSE: [[ 0.98934995]]
# iteration: 898 MSE: [[ 0.98934861]]
# iteration: 899 MSE: [[ 0.98934728]]
# iteration: 900 MSE: [[ 0.98934595]]
# iteration: 901 MSE: [[ 0.98934462]]
# iteration: 902 MSE: [[ 0.9893433]]
# iteration: 903 MSE: [[ 0.98934198]]
# iteration: 904 MSE: [[ 0.98934067]]
# iteration: 905 MSE: [[ 0.98933936]]
# iteration: 906 MSE: [[ 0.98933806]]
# iteration: 907 MSE: [[ 0.98933676]]
# iteration: 908 MSE: [[ 0.98933547]]
# iteration: 909 MSE: [[ 0.98933418]]
# iteration: 910 MSE: [[ 0.9893329]]
# iteration: 911 MSE: [[ 0.98933162]]
# iteration: 912 MSE: [[ 0.98933034]]
# iteration: 913 MSE: [[ 0.98932907]]
# iteration: 914 MSE: [[ 0.98932781]]
# iteration: 915 MSE: [[ 0.98932655]]
# iteration: 916 MSE: [[ 0.98932529]]
# iteration: 917 MSE: [[ 0.98932404]]
# iteration: 918 MSE: [[ 0.98932279]]
# iteration: 919 MSE: [[ 0.98932154]]
# iteration: 920 MSE: [[ 0.9893203]]
# iteration: 921 MSE: [[ 0.98931907]]
# iteration: 922 MSE: [[ 0.98931784]]
# iteration: 923 MSE: [[ 0.98931661]]
# iteration: 924 MSE: [[ 0.98931539]]
# iteration: 925 MSE: [[ 0.98931417]]
# iteration: 926 MSE: [[ 0.98931296]]
# iteration: 927 MSE: [[ 0.98931175]]
# iteration: 928 MSE: [[ 0.98931054]]
# iteration: 929 MSE: [[ 0.98930934]]
# iteration: 930 MSE: [[ 0.98930815]]
# iteration: 931 MSE: [[ 0.98930696]]
# iteration: 932 MSE: [[ 0.98930577]]
# iteration: 933 MSE: [[ 0.98930458]]
# iteration: 934 MSE: [[ 0.9893034]]
# iteration: 935 MSE: [[ 0.98930223]]
# iteration: 936 MSE: [[ 0.98930106]]
# iteration: 937 MSE: [[ 0.98929989]]
# iteration: 938 MSE: [[ 0.98929873]]
# iteration: 939 MSE: [[ 0.98929757]]
# iteration: 940 MSE: [[ 0.98929641]]
# iteration: 941 MSE: [[ 0.98929526]]
# iteration: 942 MSE: [[ 0.98929411]]
# iteration: 943 MSE: [[ 0.98929297]]
# iteration: 944 MSE: [[ 0.98929183]]
# iteration: 945 MSE: [[ 0.9892907]]
# iteration: 946 MSE: [[ 0.98928956]]
# iteration: 947 MSE: [[ 0.98928844]]
# iteration: 948 MSE: [[ 0.98928731]]
# iteration: 949 MSE: [[ 0.9892862]]
# iteration: 950 MSE: [[ 0.98928508]]
# iteration: 951 MSE: [[ 0.98928397]]
# iteration: 952 MSE: [[ 0.98928286]]
# iteration: 953 MSE: [[ 0.98928176]]
# iteration: 954 MSE: [[ 0.98928066]]
# iteration: 955 MSE: [[ 0.98927956]]
# iteration: 956 MSE: [[ 0.98927847]]
# iteration: 957 MSE: [[ 0.98927738]]
# iteration: 958 MSE: [[ 0.9892763]]
# iteration: 959 MSE: [[ 0.98927522]]
# iteration: 960 MSE: [[ 0.98927414]]
# iteration: 961 MSE: [[ 0.98927307]]
# iteration: 962 MSE: [[ 0.989272]]
# iteration: 963 MSE: [[ 0.98927093]]
# iteration: 964 MSE: [[ 0.98926987]]
# iteration: 965 MSE: [[ 0.98926881]]
# iteration: 966 MSE: [[ 0.98926776]]
# iteration: 967 MSE: [[ 0.98926671]]
# iteration: 968 MSE: [[ 0.98926566]]
# iteration: 969 MSE: [[ 0.98926462]]
# iteration: 970 MSE: [[ 0.98926358]]
# iteration: 971 MSE: [[ 0.98926254]]
# iteration: 972 MSE: [[ 0.98926151]]
# iteration: 973 MSE: [[ 0.98926048]]
# iteration: 974 MSE: [[ 0.98925945]]
# iteration: 975 MSE: [[ 0.98925843]]
# iteration: 976 MSE: [[ 0.98925741]]
# iteration: 977 MSE: [[ 0.9892564]]
# iteration: 978 MSE: [[ 0.98925539]]
# iteration: 979 MSE: [[ 0.98925438]]
# iteration: 980 MSE: [[ 0.98925338]]
# iteration: 981 MSE: [[ 0.98925238]]
# iteration: 982 MSE: [[ 0.98925138]]
# iteration: 983 MSE: [[ 0.98925038]]
# iteration: 984 MSE: [[ 0.98924939]]
# iteration: 985 MSE: [[ 0.98924841]]
# iteration: 986 MSE: [[ 0.98924742]]
# iteration: 987 MSE: [[ 0.98924644]]
# iteration: 988 MSE: [[ 0.98924547]]
# iteration: 989 MSE: [[ 0.98924449]]
# iteration: 990 MSE: [[ 0.98924353]]
# iteration: 991 MSE: [[ 0.98924256]]
# iteration: 992 MSE: [[ 0.9892416]]
# iteration: 993 MSE: [[ 0.98924064]]
# iteration: 994 MSE: [[ 0.98923968]]
# iteration: 995 MSE: [[ 0.98923873]]
# iteration: 996 MSE: [[ 0.98923778]]
# iteration: 997 MSE: [[ 0.98923683]]
# iteration: 998 MSE: [[ 0.98923589]]
# iteration: 999 MSE: [[ 0.98923495]]
# iteration: 1000 MSE: [[ 0.98923401]]
# iteration: 1001 MSE: [[ 0.98923308]]
# iteration: 1002 MSE: [[ 0.98923215]]
# iteration: 1003 MSE: [[ 0.98923122]]
# iteration: 1004 MSE: [[ 0.9892303]]
# iteration: 1005 MSE: [[ 0.98922938]]
# iteration: 1006 MSE: [[ 0.98922846]]
# iteration: 1007 MSE: [[ 0.98922755]]
# iteration: 1008 MSE: [[ 0.98922664]]
# iteration: 1009 MSE: [[ 0.98922573]]
# iteration: 1010 MSE: [[ 0.98922482]]
# iteration: 1011 MSE: [[ 0.98922392]]
# iteration: 1012 MSE: [[ 0.98922303]]
# iteration: 1013 MSE: [[ 0.98922213]]
# iteration: 1014 MSE: [[ 0.98922124]]
# iteration: 1015 MSE: [[ 0.98922035]]
# iteration: 1016 MSE: [[ 0.98921946]]
# iteration: 1017 MSE: [[ 0.98921858]]
# iteration: 1018 MSE: [[ 0.9892177]]
# iteration: 1019 MSE: [[ 0.98921682]]
# iteration: 1020 MSE: [[ 0.98921595]]
# iteration: 1021 MSE: [[ 0.98921508]]
# iteration: 1022 MSE: [[ 0.98921421]]
# iteration: 1023 MSE: [[ 0.98921335]]
# iteration: 1024 MSE: [[ 0.98921249]]
# iteration: 1025 MSE: [[ 0.98921163]]
# iteration: 1026 MSE: [[ 0.98921077]]
# iteration: 1027 MSE: [[ 0.98920992]]
# iteration: 1028 MSE: [[ 0.98920907]]
# iteration: 1029 MSE: [[ 0.98920822]]
# iteration: 1030 MSE: [[ 0.98920738]]
# iteration: 1031 MSE: [[ 0.98920654]]
# iteration: 1032 MSE: [[ 0.9892057]]
# iteration: 1033 MSE: [[ 0.98920487]]
# iteration: 1034 MSE: [[ 0.98920403]]
# iteration: 1035 MSE: [[ 0.9892032]]
# iteration: 1036 MSE: [[ 0.98920238]]
# iteration: 1037 MSE: [[ 0.98920155]]
# iteration: 1038 MSE: [[ 0.98920073]]
# iteration: 1039 MSE: [[ 0.98919991]]
# iteration: 1040 MSE: [[ 0.9891991]]
# iteration: 1041 MSE: [[ 0.98919829]]
# iteration: 1042 MSE: [[ 0.98919748]]
# iteration: 1043 MSE: [[ 0.98919667]]
# iteration: 1044 MSE: [[ 0.98919587]]
# iteration: 1045 MSE: [[ 0.98919507]]
# iteration: 1046 MSE: [[ 0.98919427]]
# iteration: 1047 MSE: [[ 0.98919347]]
# iteration: 1048 MSE: [[ 0.98919268]]
# iteration: 1049 MSE: [[ 0.98919189]]
# iteration: 1050 MSE: [[ 0.9891911]]
# iteration: 1051 MSE: [[ 0.98919032]]
# iteration: 1052 MSE: [[ 0.98918953]]
# iteration: 1053 MSE: [[ 0.98918875]]
# iteration: 1054 MSE: [[ 0.98918798]]
# iteration: 1055 MSE: [[ 0.9891872]]
# iteration: 1056 MSE: [[ 0.98918643]]
# iteration: 1057 MSE: [[ 0.98918566]]
# iteration: 1058 MSE: [[ 0.9891849]]
# iteration: 1059 MSE: [[ 0.98918413]]
# iteration: 1060 MSE: [[ 0.98918337]]
# iteration: 1061 MSE: [[ 0.98918262]]
# iteration: 1062 MSE: [[ 0.98918186]]
# iteration: 1063 MSE: [[ 0.98918111]]
# iteration: 1064 MSE: [[ 0.98918036]]
# iteration: 1065 MSE: [[ 0.98917961]]
# iteration: 1066 MSE: [[ 0.98917886]]
# iteration: 1067 MSE: [[ 0.98917812]]
# iteration: 1068 MSE: [[ 0.98917738]]
# iteration: 1069 MSE: [[ 0.98917664]]
# iteration: 1070 MSE: [[ 0.98917591]]
# iteration: 1071 MSE: [[ 0.98917518]]
# iteration: 1072 MSE: [[ 0.98917445]]
# iteration: 1073 MSE: [[ 0.98917372]]
# iteration: 1074 MSE: [[ 0.98917299]]
# iteration: 1075 MSE: [[ 0.98917227]]
# iteration: 1076 MSE: [[ 0.98917155]]
# iteration: 1077 MSE: [[ 0.98917083]]
# iteration: 1078 MSE: [[ 0.98917012]]
# iteration: 1079 MSE: [[ 0.98916941]]
# iteration: 1080 MSE: [[ 0.9891687]]
# iteration: 1081 MSE: [[ 0.98916799]]
# iteration: 1082 MSE: [[ 0.98916728]]
# iteration: 1083 MSE: [[ 0.98916658]]
# iteration: 1084 MSE: [[ 0.98916588]]
# iteration: 1085 MSE: [[ 0.98916518]]
# iteration: 1086 MSE: [[ 0.98916449]]
# iteration: 1087 MSE: [[ 0.98916379]]
# iteration: 1088 MSE: [[ 0.9891631]]
# iteration: 1089 MSE: [[ 0.98916241]]
# iteration: 1090 MSE: [[ 0.98916173]]
# iteration: 1091 MSE: [[ 0.98916104]]
# iteration: 1092 MSE: [[ 0.98916036]]
# iteration: 1093 MSE: [[ 0.98915968]]
# iteration: 1094 MSE: [[ 0.989159]]
# iteration: 1095 MSE: [[ 0.98915833]]
# iteration: 1096 MSE: [[ 0.98915766]]
# iteration: 1097 MSE: [[ 0.98915699]]
# iteration: 1098 MSE: [[ 0.98915632]]
# iteration: 1099 MSE: [[ 0.98915565]]
# iteration: 1100 MSE: [[ 0.98915499]]
# iteration: 1101 MSE: [[ 0.98915433]]
# iteration: 1102 MSE: [[ 0.98915367]]
# iteration: 1103 MSE: [[ 0.98915302]]
# iteration: 1104 MSE: [[ 0.98915236]]
# iteration: 1105 MSE: [[ 0.98915171]]
# iteration: 1106 MSE: [[ 0.98915106]]
# iteration: 1107 MSE: [[ 0.98915041]]
# iteration: 1108 MSE: [[ 0.98914977]]
# iteration: 1109 MSE: [[ 0.98914912]]
# iteration: 1110 MSE: [[ 0.98914848]]
# iteration: 1111 MSE: [[ 0.98914784]]
# iteration: 1112 MSE: [[ 0.98914721]]
# iteration: 1113 MSE: [[ 0.98914657]]
# iteration: 1114 MSE: [[ 0.98914594]]
# iteration: 1115 MSE: [[ 0.98914531]]
# iteration: 1116 MSE: [[ 0.98914468]]
# iteration: 1117 MSE: [[ 0.98914406]]
# iteration: 1118 MSE: [[ 0.98914343]]
# iteration: 1119 MSE: [[ 0.98914281]]
# iteration: 1120 MSE: [[ 0.98914219]]
# iteration: 1121 MSE: [[ 0.98914158]]
# iteration: 1122 MSE: [[ 0.98914096]]
# iteration: 1123 MSE: [[ 0.98914035]]
# iteration: 1124 MSE: [[ 0.98913974]]
# iteration: 1125 MSE: [[ 0.98913913]]
# iteration: 1126 MSE: [[ 0.98913852]]
# iteration: 1127 MSE: [[ 0.98913792]]
# iteration: 1128 MSE: [[ 0.98913731]]
# iteration: 1129 MSE: [[ 0.98913671]]
# iteration: 1130 MSE: [[ 0.98913612]]
# iteration: 1131 MSE: [[ 0.98913552]]
# iteration: 1132 MSE: [[ 0.98913492]]
# iteration: 1133 MSE: [[ 0.98913433]]
# iteration: 1134 MSE: [[ 0.98913374]]
# iteration: 1135 MSE: [[ 0.98913315]]
# iteration: 1136 MSE: [[ 0.98913257]]
# iteration: 1137 MSE: [[ 0.98913198]]
# iteration: 1138 MSE: [[ 0.9891314]]
# iteration: 1139 MSE: [[ 0.98913082]]
# iteration: 1140 MSE: [[ 0.98913024]]
# iteration: 1141 MSE: [[ 0.98912966]]
# iteration: 1142 MSE: [[ 0.98912909]]
# iteration: 1143 MSE: [[ 0.98912852]]
# iteration: 1144 MSE: [[ 0.98912795]]
# iteration: 1145 MSE: [[ 0.98912738]]
# iteration: 1146 MSE: [[ 0.98912681]]
# iteration: 1147 MSE: [[ 0.98912625]]
# iteration: 1148 MSE: [[ 0.98912568]]
# iteration: 1149 MSE: [[ 0.98912512]]
# iteration: 1150 MSE: [[ 0.98912456]]
# iteration: 1151 MSE: [[ 0.989124]]
# iteration: 1152 MSE: [[ 0.98912345]]
# iteration: 1153 MSE: [[ 0.9891229]]
# iteration: 1154 MSE: [[ 0.98912234]]
# iteration: 1155 MSE: [[ 0.98912179]]
# iteration: 1156 MSE: [[ 0.98912125]]
# iteration: 1157 MSE: [[ 0.9891207]]
# iteration: 1158 MSE: [[ 0.98912016]]
# iteration: 1159 MSE: [[ 0.98911961]]
# iteration: 1160 MSE: [[ 0.98911907]]
# iteration: 1161 MSE: [[ 0.98911853]]
# iteration: 1162 MSE: [[ 0.989118]]
# iteration: 1163 MSE: [[ 0.98911746]]
# iteration: 1164 MSE: [[ 0.98911693]]
# iteration: 1165 MSE: [[ 0.9891164]]
# iteration: 1166 MSE: [[ 0.98911587]]
# iteration: 1167 MSE: [[ 0.98911534]]
# iteration: 1168 MSE: [[ 0.98911481]]
# iteration: 1169 MSE: [[ 0.98911429]]
# iteration: 1170 MSE: [[ 0.98911377]]
# iteration: 1171 MSE: [[ 0.98911325]]
# iteration: 1172 MSE: [[ 0.98911273]]
# iteration: 1173 MSE: [[ 0.98911221]]
# iteration: 1174 MSE: [[ 0.98911169]]
# iteration: 1175 MSE: [[ 0.98911118]]
# iteration: 1176 MSE: [[ 0.98911067]]
# iteration: 1177 MSE: [[ 0.98911016]]
# iteration: 1178 MSE: [[ 0.98910965]]
# iteration: 1179 MSE: [[ 0.98910914]]
# iteration: 1180 MSE: [[ 0.98910864]]
# iteration: 1181 MSE: [[ 0.98910813]]
# iteration: 1182 MSE: [[ 0.98910763]]
# iteration: 1183 MSE: [[ 0.98910713]]
# iteration: 1184 MSE: [[ 0.98910663]]
# iteration: 1185 MSE: [[ 0.98910614]]
# iteration: 1186 MSE: [[ 0.98910564]]
# iteration: 1187 MSE: [[ 0.98910515]]
# iteration: 1188 MSE: [[ 0.98910466]]
# iteration: 1189 MSE: [[ 0.98910417]]
# iteration: 1190 MSE: [[ 0.98910368]]
# iteration: 1191 MSE: [[ 0.98910319]]
# iteration: 1192 MSE: [[ 0.98910271]]
# iteration: 1193 MSE: [[ 0.98910222]]
# iteration: 1194 MSE: [[ 0.98910174]]
# iteration: 1195 MSE: [[ 0.98910126]]
# iteration: 1196 MSE: [[ 0.98910078]]
# iteration: 1197 MSE: [[ 0.9891003]]
# iteration: 1198 MSE: [[ 0.98909983]]
# iteration: 1199 MSE: [[ 0.98909936]]
# iteration: 1200 MSE: [[ 0.98909888]]
# iteration: 1201 MSE: [[ 0.98909841]]
# iteration: 1202 MSE: [[ 0.98909794]]
# iteration: 1203 MSE: [[ 0.98909748]]
# iteration: 1204 MSE: [[ 0.98909701]]
# iteration: 1205 MSE: [[ 0.98909655]]
# iteration: 1206 MSE: [[ 0.98909608]]
# iteration: 1207 MSE: [[ 0.98909562]]
# iteration: 1208 MSE: [[ 0.98909516]]
# iteration: 1209 MSE: [[ 0.9890947]]
# iteration: 1210 MSE: [[ 0.98909425]]
# iteration: 1211 MSE: [[ 0.98909379]]
# iteration: 1212 MSE: [[ 0.98909334]]
# iteration: 1213 MSE: [[ 0.98909289]]
# iteration: 1214 MSE: [[ 0.98909244]]
# iteration: 1215 MSE: [[ 0.98909199]]
# iteration: 1216 MSE: [[ 0.98909154]]
# iteration: 1217 MSE: [[ 0.98909109]]
# iteration: 1218 MSE: [[ 0.98909065]]
# iteration: 1219 MSE: [[ 0.98909021]]
# iteration: 1220 MSE: [[ 0.98908976]]
# iteration: 1221 MSE: [[ 0.98908932]]
# iteration: 1222 MSE: [[ 0.98908889]]
# iteration: 1223 MSE: [[ 0.98908845]]
# iteration: 1224 MSE: [[ 0.98908801]]
# iteration: 1225 MSE: [[ 0.98908758]]
# iteration: 1226 MSE: [[ 0.98908715]]
# iteration: 1227 MSE: [[ 0.98908671]]
# iteration: 1228 MSE: [[ 0.98908628]]
# iteration: 1229 MSE: [[ 0.98908586]]
# iteration: 1230 MSE: [[ 0.98908543]]
# iteration: 1231 MSE: [[ 0.989085]]
# iteration: 1232 MSE: [[ 0.98908458]]
# iteration: 1233 MSE: [[ 0.98908416]]
# iteration: 1234 MSE: [[ 0.98908374]]
# iteration: 1235 MSE: [[ 0.98908332]]
# iteration: 1236 MSE: [[ 0.9890829]]
# iteration: 1237 MSE: [[ 0.98908248]]
# iteration: 1238 MSE: [[ 0.98908206]]
# iteration: 1239 MSE: [[ 0.98908165]]
# iteration: 1240 MSE: [[ 0.98908124]]
# iteration: 1241 MSE: [[ 0.98908083]]
# iteration: 1242 MSE: [[ 0.98908041]]
# iteration: 1243 MSE: [[ 0.98908001]]
# iteration: 1244 MSE: [[ 0.9890796]]
# iteration: 1245 MSE: [[ 0.98907919]]
# iteration: 1246 MSE: [[ 0.98907879]]
# iteration: 1247 MSE: [[ 0.98907838]]
# iteration: 1248 MSE: [[ 0.98907798]]
# iteration: 1249 MSE: [[ 0.98907758]]
# iteration: 1250 MSE: [[ 0.98907718]]
# iteration: 1251 MSE: [[ 0.98907678]]
# iteration: 1252 MSE: [[ 0.98907639]]
# iteration: 1253 MSE: [[ 0.98907599]]
# iteration: 1254 MSE: [[ 0.9890756]]
# iteration: 1255 MSE: [[ 0.98907521]]
# iteration: 1256 MSE: [[ 0.98907481]]
# iteration: 1257 MSE: [[ 0.98907442]]
# iteration: 1258 MSE: [[ 0.98907403]]
# iteration: 1259 MSE: [[ 0.98907365]]
# iteration: 1260 MSE: [[ 0.98907326]]
# iteration: 1261 MSE: [[ 0.98907288]]
# iteration: 1262 MSE: [[ 0.98907249]]
# iteration: 1263 MSE: [[ 0.98907211]]
# iteration: 1264 MSE: [[ 0.98907173]]
# iteration: 1265 MSE: [[ 0.98907135]]
# iteration: 1266 MSE: [[ 0.98907097]]
# iteration: 1267 MSE: [[ 0.98907059]]
# iteration: 1268 MSE: [[ 0.98907022]]
# iteration: 1269 MSE: [[ 0.98906984]]
# iteration: 1270 MSE: [[ 0.98906947]]
# iteration: 1271 MSE: [[ 0.9890691]]
# iteration: 1272 MSE: [[ 0.98906872]]
# iteration: 1273 MSE: [[ 0.98906836]]
# iteration: 1274 MSE: [[ 0.98906799]]
# iteration: 1275 MSE: [[ 0.98906762]]
# iteration: 1276 MSE: [[ 0.98906725]]
# iteration: 1277 MSE: [[ 0.98906689]]
# iteration: 1278 MSE: [[ 0.98906652]]
# iteration: 1279 MSE: [[ 0.98906616]]
# iteration: 1280 MSE: [[ 0.9890658]]
# iteration: 1281 MSE: [[ 0.98906544]]
# iteration: 1282 MSE: [[ 0.98906508]]
# iteration: 1283 MSE: [[ 0.98906472]]
# iteration: 1284 MSE: [[ 0.98906437]]
# iteration: 1285 MSE: [[ 0.98906401]]
# iteration: 1286 MSE: [[ 0.98906366]]
# iteration: 1287 MSE: [[ 0.9890633]]
# iteration: 1288 MSE: [[ 0.98906295]]
# iteration: 1289 MSE: [[ 0.9890626]]
# iteration: 1290 MSE: [[ 0.98906225]]
# iteration: 1291 MSE: [[ 0.9890619]]
# iteration: 1292 MSE: [[ 0.98906156]]
# iteration: 1293 MSE: [[ 0.98906121]]
# iteration: 1294 MSE: [[ 0.98906086]]
# iteration: 1295 MSE: [[ 0.98906052]]
# iteration: 1296 MSE: [[ 0.98906018]]
# iteration: 1297 MSE: [[ 0.98905984]]
# iteration: 1298 MSE: [[ 0.9890595]]
# iteration: 1299 MSE: [[ 0.98905916]]
# iteration: 1300 MSE: [[ 0.98905882]]
# iteration: 1301 MSE: [[ 0.98905848]]
# iteration: 1302 MSE: [[ 0.98905815]]
# iteration: 1303 MSE: [[ 0.98905781]]
# iteration: 1304 MSE: [[ 0.98905748]]
# iteration: 1305 MSE: [[ 0.98905714]]
# iteration: 1306 MSE: [[ 0.98905681]]
# iteration: 1307 MSE: [[ 0.98905648]]
# iteration: 1308 MSE: [[ 0.98905615]]
# iteration: 1309 MSE: [[ 0.98905582]]
# iteration: 1310 MSE: [[ 0.9890555]]
# iteration: 1311 MSE: [[ 0.98905517]]
# iteration: 1312 MSE: [[ 0.98905485]]
# iteration: 1313 MSE: [[ 0.98905452]]
# iteration: 1314 MSE: [[ 0.9890542]]
# iteration: 1315 MSE: [[ 0.98905388]]
# iteration: 1316 MSE: [[ 0.98905356]]
# iteration: 1317 MSE: [[ 0.98905324]]
# iteration: 1318 MSE: [[ 0.98905292]]
# iteration: 1319 MSE: [[ 0.9890526]]
# iteration: 1320 MSE: [[ 0.98905228]]
# iteration: 1321 MSE: [[ 0.98905197]]
# iteration: 1322 MSE: [[ 0.98905165]]
# iteration: 1323 MSE: [[ 0.98905134]]
# iteration: 1324 MSE: [[ 0.98905103]]
# iteration: 1325 MSE: [[ 0.98905072]]
# iteration: 1326 MSE: [[ 0.98905041]]
# iteration: 1327 MSE: [[ 0.9890501]]
# iteration: 1328 MSE: [[ 0.98904979]]
# iteration: 1329 MSE: [[ 0.98904948]]
# ...
# iteration: 4573 MSE: [[ 0.98895018]]
# iteration: 4574 MSE: [[ 0.98895018]]
# iteration: 4575 MSE: [[ 0.98895018]]
# iteration: 4576 MSE: [[ 0.98895018]]
# iteration: 4577 MSE: [[ 0.98895018]]
# iteration: 4578 MSE: [[ 0.98895018]]
# iteration: 4579 MSE: [[ 0.98895018]]
# iteration: 4580 MSE: [[ 0.98895018]]
# iteration: 4581 MSE: [[ 0.98895018]]
# iteration: 4582 MSE: [[ 0.98895018]]
# iteration: 4583 MSE: [[ 0.98895018]]
# iteration: 4584 MSE: [[ 0.98895018]]
# iteration: 4585 MSE: [[ 0.98895018]]
# iteration: 4586 MSE: [[ 0.98895018]]
# iteration: 4587 MSE: [[ 0.98895018]]
# iteration: 4588 MSE: [[ 0.98895018]]
# iteration: 4589 MSE: [[ 0.98895018]]
# iteration: 4590 MSE: [[ 0.98895018]]
# iteration: 4591 MSE: [[ 0.98895018]]
# iteration: 4592 MSE: [[ 0.98895018]]
# iteration: 4593 MSE: [[ 0.98895018]]
# iteration: 4594 MSE: [[ 0.98895018]]
# iteration: 4595 MSE: [[ 0.98895018]]
# iteration: 4596 MSE: [[ 0.98895018]]
# iteration: 4597 MSE: [[ 0.98895018]]
# iteration: 4598 MSE: [[ 0.98895018]]
# iteration: 4599 MSE: [[ 0.98895018]]
# iteration: 4600 MSE: [[ 0.98895018]]
# iteration: 4601 MSE: [[ 0.98895017]]
# iteration: 4602 MSE: [[ 0.98895017]]
# iteration: 4603 MSE: [[ 0.98895017]]
# iteration: 4604 MSE: [[ 0.98895017]]
# iteration: 4605 MSE: [[ 0.98895017]]
# iteration: 4606 MSE: [[ 0.98895017]]
# iteration: 4607 MSE: [[ 0.98895017]]
# iteration: 4608 MSE: [[ 0.98895017]]
# iteration: 4609 MSE: [[ 0.98895017]]
# iteration: 4610 MSE: [[ 0.98895017]]
# iteration: 4611 MSE: [[ 0.98895017]]
# iteration: 4612 MSE: [[ 0.98895017]]
# iteration: 4613 MSE: [[ 0.98895017]]
# iteration: 4614 MSE: [[ 0.98895017]]
# iteration: 4615 MSE: [[ 0.98895017]]
# iteration: 4616 MSE: [[ 0.98895017]]
# iteration: 4617 MSE: [[ 0.98895017]]
# iteration: 4618 MSE: [[ 0.98895017]]
# iteration: 4619 MSE: [[ 0.98895017]]
# iteration: 4620 MSE: [[ 0.98895017]]
# iteration: 4621 MSE: [[ 0.98895017]]
# iteration: 4622 MSE: [[ 0.98895017]]
# iteration: 4623 MSE: [[ 0.98895017]]
# iteration: 4624 MSE: [[ 0.98895017]]
# iteration: 4625 MSE: [[ 0.98895017]]
# iteration: 4626 MSE: [[ 0.98895017]]
# iteration: 4627 MSE: [[ 0.98895017]]
# iteration: 4628 MSE: [[ 0.98895017]]
# iteration: 4629 MSE: [[ 0.98895017]]
# iteration: 4630 MSE: [[ 0.98895017]]
# iteration: 4631 MSE: [[ 0.98895017]]
# iteration: 4632 MSE: [[ 0.98895017]]
# iteration: 4633 MSE: [[ 0.98895017]]
# iteration: 4634 MSE: [[ 0.98895017]]
# iteration: 4635 MSE: [[ 0.98895017]]
# iteration: 4636 MSE: [[ 0.98895017]]
# iteration: 4637 MSE: [[ 0.98895017]]
# iteration: 4638 MSE: [[ 0.98895017]]
# iteration: 4639 MSE: [[ 0.98895017]]
# iteration: 4640 MSE: [[ 0.98895017]]
# iteration: 4641 MSE: [[ 0.98895017]]
# iteration: 4642 MSE: [[ 0.98895017]]
# iteration: 4643 MSE: [[ 0.98895017]]
# iteration: 4644 MSE: [[ 0.98895017]]
# iteration: 4645 MSE: [[ 0.98895017]]
# iteration: 4646 MSE: [[ 0.98895017]]
# iteration: 4647 MSE: [[ 0.98895017]]
# iteration: 4648 MSE: [[ 0.98895017]]
# iteration: 4649 MSE: [[ 0.98895017]]
# iteration: 4650 MSE: [[ 0.98895017]]
# iteration: 4651 MSE: [[ 0.98895017]]
# iteration: 4652 MSE: [[ 0.98895017]]
# iteration: 4653 MSE: [[ 0.98895017]]
# iteration: 4654 MSE: [[ 0.98895017]]
# iteration: 4655 MSE: [[ 0.98895017]]
# iteration: 4656 MSE: [[ 0.98895017]]
# iteration: 4657 MSE: [[ 0.98895017]]
# iteration: 4658 MSE: [[ 0.98895017]]
# iteration: 4659 MSE: [[ 0.98895017]]
# iteration: 4660 MSE: [[ 0.98895017]]
# iteration: 4661 MSE: [[ 0.98895017]]
# iteration: 4662 MSE: [[ 0.98895017]]
# iteration: 4663 MSE: [[ 0.98895017]]
# iteration: 4664 MSE: [[ 0.98895017]]
# iteration: 4665 MSE: [[ 0.98895017]]
# iteration: 4666 MSE: [[ 0.98895017]]
# iteration: 4667 MSE: [[ 0.98895017]]
# iteration: 4668 MSE: [[ 0.98895017]]
# iteration: 4669 MSE: [[ 0.98895017]]
# iteration: 4670 MSE: [[ 0.98895017]]
# iteration: 4671 MSE: [[ 0.98895017]]
# iteration: 4672 MSE: [[ 0.98895017]]
# iteration: 4673 MSE: [[ 0.98895017]]
# iteration: 4674 MSE: [[ 0.98895017]]
# iteration: 4675 MSE: [[ 0.98895017]]
# iteration: 4676 MSE: [[ 0.98895016]]
# iteration: 4677 MSE: [[ 0.98895016]]
# iteration: 4678 MSE: [[ 0.98895016]]
# iteration: 4679 MSE: [[ 0.98895016]]
# iteration: 4680 MSE: [[ 0.98895016]]
# iteration: 4681 MSE: [[ 0.98895016]]
# iteration: 4682 MSE: [[ 0.98895016]]
# iteration: 4683 MSE: [[ 0.98895016]]
# iteration: 4684 MSE: [[ 0.98895016]]
# iteration: 4685 MSE: [[ 0.98895016]]
# iteration: 4686 MSE: [[ 0.98895016]]
# iteration: 4687 MSE: [[ 0.98895016]]
# iteration: 4688 MSE: [[ 0.98895016]]
# iteration: 4689 MSE: [[ 0.98895016]]
# iteration: 4690 MSE: [[ 0.98895016]]
# iteration: 4691 MSE: [[ 0.98895016]]
# iteration: 4692 MSE: [[ 0.98895016]]
# iteration: 4693 MSE: [[ 0.98895016]]
# iteration: 4694 MSE: [[ 0.98895016]]
# iteration: 4695 MSE: [[ 0.98895016]]
# iteration: 4696 MSE: [[ 0.98895016]]
# iteration: 4697 MSE: [[ 0.98895016]]
# iteration: 4698 MSE: [[ 0.98895016]]
# iteration: 4699 MSE: [[ 0.98895016]]
# iteration: 4700 MSE: [[ 0.98895016]]
# iteration: 4701 MSE: [[ 0.98895016]]
# iteration: 4702 MSE: [[ 0.98895016]]
# iteration: 4703 MSE: [[ 0.98895016]]
# iteration: 4704 MSE: [[ 0.98895016]]
# iteration: 4705 MSE: [[ 0.98895016]]
# iteration: 4706 MSE: [[ 0.98895016]]
# iteration: 4707 MSE: [[ 0.98895016]]
# iteration: 4708 MSE: [[ 0.98895016]]
# iteration: 4709 MSE: [[ 0.98895016]]
# iteration: 4710 MSE: [[ 0.98895016]]
# iteration: 4711 MSE: [[ 0.98895016]]
# iteration: 4712 MSE: [[ 0.98895016]]
# iteration: 4713 MSE: [[ 0.98895016]]
# iteration: 4714 MSE: [[ 0.98895016]]
# iteration: 4715 MSE: [[ 0.98895016]]
# iteration: 4716 MSE: [[ 0.98895016]]
# iteration: 4717 MSE: [[ 0.98895016]]
# iteration: 4718 MSE: [[ 0.98895016]]
# iteration: 4719 MSE: [[ 0.98895016]]
# iteration: 4720 MSE: [[ 0.98895016]]
# iteration: 4721 MSE: [[ 0.98895016]]
# iteration: 4722 MSE: [[ 0.98895016]]
# iteration: 4723 MSE: [[ 0.98895016]]
# iteration: 4724 MSE: [[ 0.98895016]]
# iteration: 4725 MSE: [[ 0.98895016]]
# iteration: 4726 MSE: [[ 0.98895016]]
# iteration: 4727 MSE: [[ 0.98895016]]
# iteration: 4728 MSE: [[ 0.98895016]]
# iteration: 4729 MSE: [[ 0.98895016]]
# iteration: 4730 MSE: [[ 0.98895016]]
# iteration: 4731 MSE: [[ 0.98895016]]
# iteration: 4732 MSE: [[ 0.98895016]]
# iteration: 4733 MSE: [[ 0.98895016]]
# iteration: 4734 MSE: [[ 0.98895016]]
# iteration: 4735 MSE: [[ 0.98895016]]
# iteration: 4736 MSE: [[ 0.98895016]]
# iteration: 4737 MSE: [[ 0.98895016]]
# iteration: 4738 MSE: [[ 0.98895016]]
# iteration: 4739 MSE: [[ 0.98895016]]
# iteration: 4740 MSE: [[ 0.98895016]]
# iteration: 4741 MSE: [[ 0.98895016]]
# iteration: 4742 MSE: [[ 0.98895016]]
# iteration: 4743 MSE: [[ 0.98895016]]
# iteration: 4744 MSE: [[ 0.98895016]]
# iteration: 4745 MSE: [[ 0.98895016]]
# iteration: 4746 MSE: [[ 0.98895016]]
# iteration: 4747 MSE: [[ 0.98895016]]
# iteration: 4748 MSE: [[ 0.98895016]]
# iteration: 4749 MSE: [[ 0.98895016]]
# iteration: 4750 MSE: [[ 0.98895016]]
# iteration: 4751 MSE: [[ 0.98895016]]
# iteration: 4752 MSE: [[ 0.98895016]]
# iteration: 4753 MSE: [[ 0.98895016]]
# iteration: 4754 MSE: [[ 0.98895016]]
# iteration: 4755 MSE: [[ 0.98895016]]
# iteration: 4756 MSE: [[ 0.98895016]]
# iteration: 4757 MSE: [[ 0.98895016]]
# iteration: 4758 MSE: [[ 0.98895016]]
# iteration: 4759 MSE: [[ 0.98895016]]
# iteration: 4760 MSE: [[ 0.98895016]]
# iteration: 4761 MSE: [[ 0.98895016]]
# iteration: 4762 MSE: [[ 0.98895016]]
# iteration: 4763 MSE: [[ 0.98895015]]
# iteration: 4764 MSE: [[ 0.98895015]]
# iteration: 4765 MSE: [[ 0.98895015]]
# iteration: 4766 MSE: [[ 0.98895015]]
# iteration: 4767 MSE: [[ 0.98895015]]
# iteration: 4768 MSE: [[ 0.98895015]]
# iteration: 4769 MSE: [[ 0.98895015]]
# iteration: 4770 MSE: [[ 0.98895015]]
# iteration: 4771 MSE: [[ 0.98895015]]
# iteration: 4772 MSE: [[ 0.98895015]]
# iteration: 4773 MSE: [[ 0.98895015]]
# iteration: 4774 MSE: [[ 0.98895015]]
# iteration: 4775 MSE: [[ 0.98895015]]
# iteration: 4776 MSE: [[ 0.98895015]]
# iteration: 4777 MSE: [[ 0.98895015]]
# iteration: 4778 MSE: [[ 0.98895015]]
# iteration: 4779 MSE: [[ 0.98895015]]
# iteration: 4780 MSE: [[ 0.98895015]]
# iteration: 4781 MSE: [[ 0.98895015]]
# iteration: 4782 MSE: [[ 0.98895015]]
# iteration: 4783 MSE: [[ 0.98895015]]
# iteration: 4784 MSE: [[ 0.98895015]]
# iteration: 4785 MSE: [[ 0.98895015]]
# iteration: 4786 MSE: [[ 0.98895015]]
# iteration: 4787 MSE: [[ 0.98895015]]
# iteration: 4788 MSE: [[ 0.98895015]]
# iteration: 4789 MSE: [[ 0.98895015]]
# iteration: 4790 MSE: [[ 0.98895015]]
# iteration: 4791 MSE: [[ 0.98895015]]
# iteration: 4792 MSE: [[ 0.98895015]]
# iteration: 4793 MSE: [[ 0.98895015]]
# iteration: 4794 MSE: [[ 0.98895015]]
# iteration: 4795 MSE: [[ 0.98895015]]
# iteration: 4796 MSE: [[ 0.98895015]]
# iteration: 4797 MSE: [[ 0.98895015]]
# iteration: 4798 MSE: [[ 0.98895015]]
# iteration: 4799 MSE: [[ 0.98895015]]
# iteration: 4800 MSE: [[ 0.98895015]]
# iteration: 4801 MSE: [[ 0.98895015]]
# iteration: 4802 MSE: [[ 0.98895015]]
# iteration: 4803 MSE: [[ 0.98895015]]
# iteration: 4804 MSE: [[ 0.98895015]]
# iteration: 4805 MSE: [[ 0.98895015]]
# iteration: 4806 MSE: [[ 0.98895015]]
# iteration: 4807 MSE: [[ 0.98895015]]
# iteration: 4808 MSE: [[ 0.98895015]]
# iteration: 4809 MSE: [[ 0.98895015]]
# iteration: 4810 MSE: [[ 0.98895015]]
# iteration: 4811 MSE: [[ 0.98895015]]
# iteration: 4812 MSE: [[ 0.98895015]]
# iteration: 4813 MSE: [[ 0.98895015]]
# iteration: 4814 MSE: [[ 0.98895015]]
# iteration: 4815 MSE: [[ 0.98895015]]
# iteration: 4816 MSE: [[ 0.98895015]]
# iteration: 4817 MSE: [[ 0.98895015]]
# iteration: 4818 MSE: [[ 0.98895015]]
# iteration: 4819 MSE: [[ 0.98895015]]
# iteration: 4820 MSE: [[ 0.98895015]]
# iteration: 4821 MSE: [[ 0.98895015]]
# iteration: 4822 MSE: [[ 0.98895015]]
# iteration: 4823 MSE: [[ 0.98895015]]
# iteration: 4824 MSE: [[ 0.98895015]]
# iteration: 4825 MSE: [[ 0.98895015]]
# iteration: 4826 MSE: [[ 0.98895015]]
# iteration: 4827 MSE: [[ 0.98895015]]
# iteration: 4828 MSE: [[ 0.98895015]]
# iteration: 4829 MSE: [[ 0.98895015]]
# iteration: 4830 MSE: [[ 0.98895015]]
# iteration: 4831 MSE: [[ 0.98895015]]
# iteration: 4832 MSE: [[ 0.98895015]]
# iteration: 4833 MSE: [[ 0.98895015]]
# iteration: 4834 MSE: [[ 0.98895015]]
# iteration: 4835 MSE: [[ 0.98895015]]
# iteration: 4836 MSE: [[ 0.98895015]]
# iteration: 4837 MSE: [[ 0.98895015]]
# iteration: 4838 MSE: [[ 0.98895015]]
# iteration: 4839 MSE: [[ 0.98895015]]
# iteration: 4840 MSE: [[ 0.98895015]]
# iteration: 4841 MSE: [[ 0.98895015]]
# iteration: 4842 MSE: [[ 0.98895015]]
# iteration: 4843 MSE: [[ 0.98895015]]
# iteration: 4844 MSE: [[ 0.98895015]]
# iteration: 4845 MSE: [[ 0.98895015]]
# iteration: 4846 MSE: [[ 0.98895015]]
# iteration: 4847 MSE: [[ 0.98895015]]
# iteration: 4848 MSE: [[ 0.98895015]]
# iteration: 4849 MSE: [[ 0.98895015]]
# iteration: 4850 MSE: [[ 0.98895015]]
# iteration: 4851 MSE: [[ 0.98895015]]
# iteration: 4852 MSE: [[ 0.98895015]]
# iteration: 4853 MSE: [[ 0.98895015]]
# iteration: 4854 MSE: [[ 0.98895015]]
# iteration: 4855 MSE: [[ 0.98895015]]
# iteration: 4856 MSE: [[ 0.98895015]]
# iteration: 4857 MSE: [[ 0.98895015]]
# iteration: 4858 MSE: [[ 0.98895015]]
# iteration: 4859 MSE: [[ 0.98895015]]
# iteration: 4860 MSE: [[ 0.98895015]]
# iteration: 4861 MSE: [[ 0.98895015]]
# iteration: 4862 MSE: [[ 0.98895015]]
# iteration: 4863 MSE: [[ 0.98895015]]
# iteration: 4864 MSE: [[ 0.98895014]]
# iteration: 4865 MSE: [[ 0.98895014]]
# iteration: 4866 MSE: [[ 0.98895014]]
# iteration: 4867 MSE: [[ 0.98895014]]
# iteration: 4868 MSE: [[ 0.98895014]]
# iteration: 4869 MSE: [[ 0.98895014]]
# iteration: 4870 MSE: [[ 0.98895014]]
# iteration: 4871 MSE: [[ 0.98895014]]
# iteration: 4872 MSE: [[ 0.98895014]]
# iteration: 4873 MSE: [[ 0.98895014]]
# iteration: 4874 MSE: [[ 0.98895014]]
# iteration: 4875 MSE: [[ 0.98895014]]
# iteration: 4876 MSE: [[ 0.98895014]]
# iteration: 4877 MSE: [[ 0.98895014]]
# iteration: 4878 MSE: [[ 0.98895014]]
# iteration: 4879 MSE: [[ 0.98895014]]
# iteration: 4880 MSE: [[ 0.98895014]]
# iteration: 4881 MSE: [[ 0.98895014]]
# iteration: 4882 MSE: [[ 0.98895014]]
# iteration: 4883 MSE: [[ 0.98895014]]
# iteration: 4884 MSE: [[ 0.98895014]]
# iteration: 4885 MSE: [[ 0.98895014]]
# iteration: 4886 MSE: [[ 0.98895014]]
# iteration: 4887 MSE: [[ 0.98895014]]
# iteration: 4888 MSE: [[ 0.98895014]]
# iteration: 4889 MSE: [[ 0.98895014]]
# iteration: 4890 MSE: [[ 0.98895014]]
# iteration: 4891 MSE: [[ 0.98895014]]
# iteration: 4892 MSE: [[ 0.98895014]]
# iteration: 4893 MSE: [[ 0.98895014]]
# iteration: 4894 MSE: [[ 0.98895014]]
# iteration: 4895 MSE: [[ 0.98895014]]
# iteration: 4896 MSE: [[ 0.98895014]]
# iteration: 4897 MSE: [[ 0.98895014]]
# iteration: 4898 MSE: [[ 0.98895014]]
# iteration: 4899 MSE: [[ 0.98895014]]
# iteration: 4900 MSE: [[ 0.98895014]]
# iteration: 4901 MSE: [[ 0.98895014]]
# iteration: 4902 MSE: [[ 0.98895014]]
# iteration: 4903 MSE: [[ 0.98895014]]
# iteration: 4904 MSE: [[ 0.98895014]]
# iteration: 4905 MSE: [[ 0.98895014]]
# iteration: 4906 MSE: [[ 0.98895014]]
# iteration: 4907 MSE: [[ 0.98895014]]
# iteration: 4908 MSE: [[ 0.98895014]]
# iteration: 4909 MSE: [[ 0.98895014]]
# iteration: 4910 MSE: [[ 0.98895014]]
# iteration: 4911 MSE: [[ 0.98895014]]
# iteration: 4912 MSE: [[ 0.98895014]]
# iteration: 4913 MSE: [[ 0.98895014]]
# iteration: 4914 MSE: [[ 0.98895014]]
# iteration: 4915 MSE: [[ 0.98895014]]
# iteration: 4916 MSE: [[ 0.98895014]]
# iteration: 4917 MSE: [[ 0.98895014]]
# iteration: 4918 MSE: [[ 0.98895014]]
# iteration: 4919 MSE: [[ 0.98895014]]
# iteration: 4920 MSE: [[ 0.98895014]]
# iteration: 4921 MSE: [[ 0.98895014]]
# iteration: 4922 MSE: [[ 0.98895014]]
# iteration: 4923 MSE: [[ 0.98895014]]
# iteration: 4924 MSE: [[ 0.98895014]]
# iteration: 4925 MSE: [[ 0.98895014]]
# iteration: 4926 MSE: [[ 0.98895014]]
# iteration: 4927 MSE: [[ 0.98895014]]
# iteration: 4928 MSE: [[ 0.98895014]]
# iteration: 4929 MSE: [[ 0.98895014]]
# iteration: 4930 MSE: [[ 0.98895014]]
# iteration: 4931 MSE: [[ 0.98895014]]
# iteration: 4932 MSE: [[ 0.98895014]]
# iteration: 4933 MSE: [[ 0.98895014]]
# iteration: 4934 MSE: [[ 0.98895014]]
# iteration: 4935 MSE: [[ 0.98895014]]
# iteration: 4936 MSE: [[ 0.98895014]]
# iteration: 4937 MSE: [[ 0.98895014]]
# iteration: 4938 MSE: [[ 0.98895014]]
# iteration: 4939 MSE: [[ 0.98895014]]
# iteration: 4940 MSE: [[ 0.98895014]]
# iteration: 4941 MSE: [[ 0.98895014]]
# iteration: 4942 MSE: [[ 0.98895014]]
# iteration: 4943 MSE: [[ 0.98895014]]
# iteration: 4944 MSE: [[ 0.98895014]]
# iteration: 4945 MSE: [[ 0.98895014]]
# iteration: 4946 MSE: [[ 0.98895014]]
# iteration: 4947 MSE: [[ 0.98895014]]
# iteration: 4948 MSE: [[ 0.98895014]]
# iteration: 4949 MSE: [[ 0.98895014]]
# iteration: 4950 MSE: [[ 0.98895014]]
# iteration: 4951 MSE: [[ 0.98895014]]
# iteration: 4952 MSE: [[ 0.98895014]]
# iteration: 4953 MSE: [[ 0.98895014]]
# iteration: 4954 MSE: [[ 0.98895014]]
# iteration: 4955 MSE: [[ 0.98895014]]
# iteration: 4956 MSE: [[ 0.98895014]]
# iteration: 4957 MSE: [[ 0.98895014]]
# iteration: 4958 MSE: [[ 0.98895014]]
# iteration: 4959 MSE: [[ 0.98895014]]
# iteration: 4960 MSE: [[ 0.98895014]]
# iteration: 4961 MSE: [[ 0.98895014]]
# iteration: 4962 MSE: [[ 0.98895014]]
# iteration: 4963 MSE: [[ 0.98895014]]
# iteration: 4964 MSE: [[ 0.98895014]]
# iteration: 4965 MSE: [[ 0.98895014]]
# iteration: 4966 MSE: [[ 0.98895014]]
# iteration: 4967 MSE: [[ 0.98895014]]
# iteration: 4968 MSE: [[ 0.98895014]]
# iteration: 4969 MSE: [[ 0.98895014]]
# iteration: 4970 MSE: [[ 0.98895014]]
# iteration: 4971 MSE: [[ 0.98895014]]
# iteration: 4972 MSE: [[ 0.98895014]]
# iteration: 4973 MSE: [[ 0.98895014]]
# iteration: 4974 MSE: [[ 0.98895014]]
# iteration: 4975 MSE: [[ 0.98895014]]
# iteration: 4976 MSE: [[ 0.98895014]]
# iteration: 4977 MSE: [[ 0.98895014]]
# iteration: 4978 MSE: [[ 0.98895014]]
# iteration: 4979 MSE: [[ 0.98895014]]
# iteration: 4980 MSE: [[ 0.98895014]]
# iteration: 4981 MSE: [[ 0.98895014]]
# iteration: 4982 MSE: [[ 0.98895014]]
# iteration: 4983 MSE: [[ 0.98895014]]
# iteration: 4984 MSE: [[ 0.98895014]]
# iteration: 4985 MSE: [[ 0.98895014]]
# iteration: 4986 MSE: [[ 0.98895014]]
# iteration: 4987 MSE: [[ 0.98895013]]
# iteration: 4988 MSE: [[ 0.98895013]]
# iteration: 4989 MSE: [[ 0.98895013]]
# iteration: 4990 MSE: [[ 0.98895013]]
# iteration: 4991 MSE: [[ 0.98895013]]
# iteration: 4992 MSE: [[ 0.98895013]]
# iteration: 4993 MSE: [[ 0.98895013]]
# iteration: 4994 MSE: [[ 0.98895013]]
# iteration: 4995 MSE: [[ 0.98895013]]
# iteration: 4996 MSE: [[ 0.98895013]]
# iteration: 4997 MSE: [[ 0.98895013]]
# iteration: 4998 MSE: [[ 0.98895013]]
# iteration: 4999 MSE: [[ 0.98895013]]
# [[ 0.05540933]
#  [-0.09433413]
#  [-0.12224504]
#  [ 0.23445498]
#  [-0.07524816]
#  [ 0.36774164]
#  [-0.1011265 ]
#  [ 0.25173315]
#  [-0.39591745]
#  [-0.2733537 ]
#  [ 0.13598678]]

# %% [markdown]
# > https://mubaris.com/2017/09/28/linear-regression-from-scratch/
#
#
# > http://blog.csdn.net/bryan__/article/details/52338151
#
# > https://ask.hellobi.com/blog/guodongwei1991/9076
#
# > http://web.mit.edu/zoya/www/linearRegression.pdf
#
# > http://www.cs.cmu.edu/~aarti/Class/10701_Spring14/slides/linear_regression.pdf
#
# > https://webdocs.cs.ualberta.ca/~rgreiner/C-466/SLIDES/3b-Regression.pdf
#
# > http://vda.univie.ac.at/Teaching/ML/15s/LectureNotes/03_regression.pdf
#
# > http://blog.csdn.net/qq_34531825/article/details/52689654
#
# > http://freemind.pluskid.org/machine-learning/sparsity-and-some-basics-of-l1-regularization/#ed61992b37932e208ae114be75e42a3e6dc34cb3
#
# > http://www.52caml.com/head_first_ml/ml-chapter1-regression-family/
